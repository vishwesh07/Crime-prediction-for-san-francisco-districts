# %%
import pandas as pd
import numpy as np
results_df = pd.read_csv('SFPD_dataset.csv',encoding = "ISO-8859-1")

# %%
print(len(results_df))
# Out:
# 2207110

# %%
results_df.index
# Out:
# RangeIndex(start=0, stop=2207110, step=1)

# %%
results_df.columns
# Out:
# Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')

# %%
results_df.values
# Out:
# array([['5400 Block of CALIFORNIA ST', 'VEHICLE THEFT',
#         '2015-08-29T00:00:00.000', ..., '13:51', -122.475917940378,
#         37.7843496645156],
#        ['2300 Block of MISSION ST', 'DRUG/NARCOTIC',
#         '2017-06-22T00:00:00.000', ..., '16:15', -122.41905886810274,
#         37.75942275062965],
#        ['0 Block of SPOFFORD LN', 'DRUG/NARCOTIC',
#         '2017-11-06T00:00:00.000', ..., '17:06', -122.40732139433702,
#         37.79458624443584],
#        ...,
#        ['1700 Block of HAIGHT ST', 'OTHER OFFENSES',
#         '2016-06-01T00:00:00.000', ..., '22:55', -122.4512880612313,
#         37.76939670991646],
#        ['1500 Block of GREENWICH ST', 'OTHER OFFENSES',
#         '2016-05-05T00:00:00.000', ..., '07:51', -122.42518476656386,
#         37.800254402551815],
#        ['300 Block of FELL ST', 'VANDALISM', '2016-04-05T00:00:00.000',
#         ..., '05:01', -122.42358185743696, 37.77590426738279]], dtype=object)

# %%
address = results_df.address.unique()
category = results_df.category.unique()
dayofweek = results_df.dayofweek.unique()
descript = results_df.descript.unique()
# location = results_df.location.unique()
pddistrict = results_df.pddistrict.unique()
date = results_df.date.unique()
time = results_df.time.unique()
X = results_df.x.unique()
Y = results_df.y.unique()
incedent_number = results_df.incidntnum.unique()
pdid = results_df.pdid.unique()
resolution = results_df.resolution.unique()

# %%
print("Unique values of attributes: ")
print("Address", len(address))
print("Category", len(category))
print("Day of week", len(dayofweek))
print("Descript", len(descript))
print("Pd district", len(pddistrict))
print("Date",len(date))
print("Time", len(time))
print("X", len(X))
print("Y", len(Y))
print("Incedent Number", len(incedent_number))
print("Pd Id", len(pdid))
print("Resolution", len(resolution))
# Out:
# Unique values of attributes:
# Address 25141
# Category 39
# Day of week 7
# Descript 915
# Pd district 11
# Date 5587
# Time 1439
# X 60498
# Y 58562
# Incedent Number 1740910
# Pd Id 2207110
# Resolution 17

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2207110 entries, 0 to 2207109
# Data columns (total 13 columns):
# address       object
# category      object
# date          object
# dayofweek     object
# descript      object
# incidntnum    int64
# location      object
# pddistrict    object
# pdid          int64
# resolution    object
# time          object
# x             float64
# y             float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 218.9+ MB

# %%
print(len(category))
# Out:
# 39

# %%
df_list = set()
for v in results_df['pddistrict']:
    if isinstance(v,str):
        df_list.add(v)

# %%
df_list
# Out:
# {'BAYVIEW',
#  'CENTRAL',
#  'INGLESIDE',
#  'MISSION',
#  'NORTHERN',
#  'PARK',
#  'RICHMOND',
#  'SOUTHERN',
#  'TARAVAL',
#  'TENDERLOIN'}

# %%
# Save data for whole city in 'SFPD_dataset'
# results_df.to_csv('SFPD_dataset.csv',index=False,header=True, columns=['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
district_data = dict()

# %%
# Save data for different district in different dataframe

# %%
mask = results_df['pddistrict'] == 'BAYVIEW'
district_data['BAYVIEW'] = results_df[mask]
# df_BAYVIEW.to_csv('BAYVIEW_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'CENTRAL'
district_data['CENTRAL'] = results_df[mask]
# df_CENTRAL.to_csv('CENTRAL_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'INGLESIDE'
district_data['INGLESIDE'] = results_df[mask]
# df_INGLESIDE.to_csv('INGLESIDE_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'MISSION'
district_data['MISSION'] = results_df[mask]
# df_MISSION.to_csv('MISSION_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'NORTHERN'
district_data['NORTHERN'] = results_df[mask]
# df_NORTHERN.to_csv('NORTHERN_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'SOUTHERN'
district_data['SOUTHERN'] = results_df[mask]
# df_SOUTHERN.to_csv('SOUTHERN_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'TARAVAL'
district_data['TARAVAL'] = results_df[mask]
# df_TARAVAL.to_csv('TARAVAL_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'TENDERLOIN'
district_data['TENDERLOIN'] = results_df[mask]
# df_TENDERLOIN.to_csv('TENDERLOIN_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'PARK'
district_data['PARK'] = results_df[mask]
# df_PARK.to_csv('PARK_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
mask = results_df['pddistrict'] == 'RICHMOND'
district_data['RICHMOND'] = results_df[mask]
# df_RICHMOND.to_csv('RICHMOND_data', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'])

# %%
city_data = dict()
city_data['City'] = results_df

# %%
# Identify and Remove null values
print("Null values in attributes: ")
null_columns=results_df.columns[results_df.isnull().any()]
results_df[null_columns].isnull().sum()
# Out:
# Null values in attributes:
# pddistrict    1
# dtype: int64

# %% [markdown]
# # Build District wise Models and City wise Model

# %%
print("District wise incidents -\n")
for key in district_data:
    district = district_data[key]
    print(key,"-",district.shape[0])
print(" \nMax incedent district - Southern - 398271")
print("\nMin incedent district - PARK - 124997")

# Plot incedents in each district
# from matplotlib import pyplot as plt
# plt.plot()
# Out:
# District wise incidents -
#
# BAYVIEW - 220292
# CENTRAL - 225332
# INGLESIDE - 193560
# MISSION - 298918
# NORTHERN - 271737
# SOUTHERN - 398271
# TARAVAL - 166393
# TENDERLOIN - 191220
# PARK - 124997
# RICHMOND - 116389
#
# Max incedent district - Southern - 398271
#
# Min incedent district - PARK - 124997

# %% [markdown]
# # Program Strating Point for Data Science Life Cycle Phases

# %%
accuracy_dictionary = dict()

for key in district_data:
    district = district_data[key]
    process_district(district, key)
# Out:
# Dataframe info -
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 220292 entries, 3 to 2207104
# Data columns (total 13 columns):
# address       220292 non-null object
# category      220292 non-null object
# date          220292 non-null object
# dayofweek     220292 non-null object
# descript      220292 non-null object
# incidntnum    220292 non-null int64
# location      220292 non-null object
# pddistrict    220292 non-null object
# pdid          220292 non-null int64
# resolution    220292 non-null object
# time          220292 non-null object
# x             220292 non-null float64
# y             220292 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 23.5+ MB
# None
#
# Features - Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')
#
# Unique values of features for BAYVIEW district:
#
# Address 3787
# Category 39
# Day of week 7
# Descript 757
# Pd district 1
# Date 5586
# Time 1439
# X 7898
# Y 7653
# Incedent Number 170405
# Pd Id 220292
# Resolution 17
#
# Before removing null and duplicates - Rows - 220292
# Before removing null and duplicates - Columns - 5
#
# After removing null and duplicates - Rows - 201078
# After removing null and duplicates - Columns - 5
#
# Remaining features - Index(['address', 'category', 'date', 'dayofweek', 'time'], dtype='object')
#
# Preprocessed BAYVIEW district Dataframe -
#
#                                 address           category  \
# 3                 1000 BLOCK OF KEY AV     MISSING PERSON
# 7           1500 BLOCK OF UNDERWOOD AV     OTHER OFFENSES
# 45                MCKINNON AV / 3RD ST        WEAPON LAWS
# 58          2900 BLOCK OF SAN BRUNO AV        WEAPON LAWS
# 72        600 BLOCK OF PENNSYLVANIA AV            ASSAULT
# 97            1000 BLOCK OF OAKDALE AV     SUSPICIOUS OCC
# 111         3000 BLOCK OF SAN BRUNO AV    STOLEN PROPERTY
# 116                DEHARO ST / 15TH ST           WARRANTS
# 125           200 BLOCK OF WILLIAMS AV       NON-CRIMINAL
# 147         2300 BLOCK OF SAN BRUNO AV            ASSAULT
# 152          1500 BLOCK OF KIRKWOOD AV     SUSPICIOUS OCC
# 153               5400 BLOCK OF 3RD ST       NON-CRIMINAL
# 190                 HOOPER ST / 7TH ST            ASSAULT
# 200               0 BLOCK OF BOWMAN CT  RECOVERED VEHICLE
# 203              100 BLOCK OF COLBY ST            ASSAULT
# 223           3000 BLOCK OF INGALLS ST            ROBBERY
# 229           1400 BLOCK OF LASALLE AV      LARCENY/THEFT
# 238                17TH ST / KANSAS ST      VEHICLE THEFT
# 259              0 BLOCK OF ROBBLEE AV      VEHICLE THEFT
# 260                DEHARO ST / 23RD ST       NON-CRIMINAL
# 289           JENNINGS ST / NEWHALL ST       NON-CRIMINAL
# 293           1700 BLOCK OF QUESADA AV            ASSAULT
# 297           1500 BLOCK OF OAKDALE AV     SUSPICIOUS OCC
# 301             100 BLOCK OF HARBOR RD       NON-CRIMINAL
# 311               0 BLOCK OF DAKOTA ST     MISSING PERSON
# 315         2400 BLOCK OF SAN BRUNO AV      LARCENY/THEFT
# 319          1600 BLOCK OF MCKINNON AV     MISSING PERSON
# 331             1800 BLOCK OF EVANS AV       NON-CRIMINAL
# 347               1400 BLOCK OF 3RD ST            ASSAULT
# 364             600 BLOCK OF AMADOR ST     OTHER OFFENSES
# ...                                ...                ...
# 2206729         0 BLOCK OF BEATRICE LN            ASSAULT
# 2206733      0 BLOCK OF MIDDLEPOINT RD     OTHER OFFENSES
# 2206739       1400 BLOCK OF VANDYKE AV     OTHER OFFENSES
# 2206752     2400 BLOCK OF SAN BRUNO AV           BURGLARY
# 2206777         700 BLOCK OF KANSAS ST      VEHICLE THEFT
# 2206778         1700 BLOCK OF QUINT ST            ASSAULT
# 2206787           LANE ST / VANDYKE AV            ASSAULT
# 2206797           1200 BLOCK OF 3RD ST           TRESPASS
# 2206802       1200 BLOCK OF QUESADA AV       NON-CRIMINAL
# 2206807          0 BLOCK OF BAYVIEW ST       NON-CRIMINAL
# 2206816  1700 BLOCK OF CESAR CHAVEZ ST          VANDALISM
# 2206858           0 BLOCK OF TOPEKA AV       NON-CRIMINAL
# 2206864           0 BLOCK OF LATONA ST     OTHER OFFENSES
# 2206878       HAMILTON ST / BURROWS ST      VEHICLE THEFT
# 2206890        1400 BLOCK OF DEHARO ST    FAMILY OFFENSES
# 2206907          0 BLOCK OF SANTAFE AV     OTHER OFFENSES
# 2206947           3700 BLOCK OF 3RD ST      VEHICLE THEFT
# 2206955            3RD ST / FAIRFAX AV      DRUG/NARCOTIC
# 2206966         800 BLOCK OF RANKIN ST            ASSAULT
# 2206984              3RD ST / PALOU AV      DRUG/NARCOTIC
# 2206998       100 BLOCK OF MISSOURI ST      LARCENY/THEFT
# 2207003           PHELPS ST / EVANS AV       NON-CRIMINAL
# 2207018        JENNINGS ST / REVERE AV      VEHICLE THEFT
# 2207020         0 BLOCK OF CASHMERE ST     OTHER OFFENSES
# 2207051          0 BLOCK OF OSCEOLA LN     SUSPICIOUS OCC
# 2207065       0 BLOCK OF NORTHRIDGE RD        WEAPON LAWS
# 2207072         1100 BLOCK OF PALOU AV  RECOVERED VEHICLE
# 2207082         2100 BLOCK OF PALOU AV              FRAUD
# 2207089       1700 BLOCK OF LASALLE AV           WARRANTS
# 2207104       200 BLOCK OF WILLIAMS AV     OTHER OFFENSES
#
#                             date  dayofweek   time
# 3        2017-08-01T00:00:00.000    Tuesday  20:00
# 7        2015-06-21T00:00:00.000     Sunday  04:08
# 45       2015-08-03T00:00:00.000     Monday  23:33
# 58       2013-05-08T00:00:00.000  Wednesday  22:45
# 72       2015-07-15T00:00:00.000  Wednesday  15:30
# 97       2013-05-02T00:00:00.000   Thursday  20:52
# 111      2013-04-20T00:00:00.000   Saturday  12:25
# 116      2013-04-26T00:00:00.000     Friday  20:53
# 125      2013-05-22T00:00:00.000  Wednesday  16:00
# 147      2015-07-26T00:00:00.000     Sunday  14:03
# 152      2013-06-23T00:00:00.000     Sunday  00:01
# 153      2013-06-04T00:00:00.000    Tuesday  10:18
# 190      2015-07-07T00:00:00.000    Tuesday  11:55
# 200      2015-05-31T00:00:00.000     Sunday  17:48
# 203      2015-07-06T00:00:00.000     Monday  13:26
# 223      2013-04-28T00:00:00.000     Sunday  19:50
# 229      2015-06-02T00:00:00.000    Tuesday  19:00
# 238      2015-04-24T00:00:00.000     Friday  10:00
# 259      2012-11-25T00:00:00.000     Sunday  18:30
# 260      2012-07-15T00:00:00.000     Sunday  02:30
# 289      2015-07-07T00:00:00.000    Tuesday  16:45
# 293      2015-08-29T00:00:00.000   Saturday  05:23
# 297      2015-07-05T00:00:00.000     Sunday  06:20
# 301      2015-08-06T00:00:00.000   Thursday  08:15
# 311      2015-06-25T00:00:00.000   Thursday  06:30
# 315      2015-08-21T00:00:00.000     Friday  18:50
# 319      2015-08-07T00:00:00.000     Friday  13:00
# 331      2015-03-05T00:00:00.000   Thursday  23:00
# 347      2017-03-24T00:00:00.000     Friday  22:00
# 364      2015-09-05T00:00:00.000   Saturday  20:32
# ...                          ...        ...    ...
# 2206729  2016-06-15T00:00:00.000  Wednesday  20:30
# 2206733  2016-04-10T00:00:00.000     Sunday  10:15
# 2206739  2016-04-29T00:00:00.000     Friday  10:00
# 2206752  2016-02-28T00:00:00.000     Sunday  16:25
# 2206777  2016-04-28T00:00:00.000   Thursday  21:00
# 2206778  2016-06-03T00:00:00.000     Friday  16:45
# 2206787  2016-05-28T00:00:00.000   Saturday  21:30
# 2206797  2016-03-06T00:00:00.000     Sunday  17:21
# 2206802  2016-04-13T00:00:00.000  Wednesday  09:00
# 2206807  2016-03-19T00:00:00.000   Saturday  10:37
# 2206816  2016-02-28T00:00:00.000     Sunday  04:44
# 2206858  2016-04-08T00:00:00.000     Friday  16:00
# 2206864  2016-05-21T00:00:00.000   Saturday  00:01
# 2206878  2016-04-26T00:00:00.000    Tuesday  15:00
# 2206890  2016-03-10T00:00:00.000   Thursday  17:09
# 2206907  2016-03-14T00:00:00.000     Monday  12:00
# 2206947  2016-04-30T00:00:00.000   Saturday  07:00
# 2206955  2016-05-16T00:00:00.000     Monday  08:36
# 2206966  2016-05-19T00:00:00.000   Thursday  01:00
# 2206984  2016-03-05T00:00:00.000   Saturday  12:56
# 2206998  2016-06-01T00:00:00.000  Wednesday  18:15
# 2207003  2016-03-20T00:00:00.000     Sunday  13:06
# 2207018  2016-04-11T00:00:00.000     Monday  23:00
# 2207020  2016-04-25T00:00:00.000     Monday  22:00
# 2207051  2016-05-27T00:00:00.000     Friday  20:13
# 2207065  2016-05-15T00:00:00.000     Sunday  20:48
# 2207072  2016-04-30T00:00:00.000   Saturday  14:07
# 2207082  2016-06-06T00:00:00.000     Monday  15:45
# 2207089  2016-03-02T00:00:00.000  Wednesday  08:41
# 2207104  2016-06-19T00:00:00.000     Sunday  00:50
#
# [201078 rows x 5 columns]
# After adding features - Rows - 201078
# After adding features - Columns - 9
#
# New features - Index(['address', 'category', 'date', 'dayofweek', 'time', 'day', 'month',
#        'hour', 'year'],
#       dtype='object')
#
# Unique crime categories - ['MISSING PERSON' 'OTHER OFFENSES' 'WEAPON LAWS' 'ASSAULT' 'SUSPICIOUS OCC'
#  'STOLEN PROPERTY' 'WARRANTS' 'NON-CRIMINAL' 'RECOVERED VEHICLE' 'ROBBERY'
#  'LARCENY/THEFT' 'VEHICLE THEFT' 'BURGLARY' 'VANDALISM' 'SECONDARY CODES'
#  'EMBEZZLEMENT' 'FRAUD' 'LOITERING' 'FAMILY OFFENSES'
#  'SEX OFFENSES, FORCIBLE' 'FORGERY/COUNTERFEITING' 'BRIBERY' 'TRESPASS'
#  'ARSON' 'DRUG/NARCOTIC' 'DRUNKENNESS' 'KIDNAPPING' 'RUNAWAY' 'GAMBLING'
#  'EXTORTION' 'PROSTITUTION' 'LIQUOR LAWS' 'DRIVING UNDER THE INFLUENCE'
#  'DISORDERLY CONDUCT' 'BAD CHECKS' 'SUICIDE' 'SEX OFFENSES, NON FORCIBLE'
#  'TREA' 'PORNOGRAPHY/OBSCENE MAT']
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
#  district_acmdh - Index Crime - Mean - 1.1094262348199126
#
#  district_acmdh - Non Index Crime - Mean - 1.2248149169512739
#
# Index Crime Hotspots - 1562
#
# Non Index Crime Hotspots - 2290
#
# Total Index and Non Index Crime Hotspots - 2516
#
# Before considering hotspots - Rows - 201078
# Before considering hotspots - Columns - 5
#
# After considering hotspots - Rows - 193281
# After considering hotspots - Columns - 5
#
# Data shrunk from 201078  rows to 193281 rows - By ~ 99.03877599737416 % - for  BAYVIEW district.
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
# Target shape (193281,)
#
# Features shape (193281, 4)
#
# Index - Non Index crime counts -
#  Index Crime (More Serious)         81202
# Non Index Crime (Less Serious)    112079
# dtype: int64
#
# Unique values of attributes for  BAYVIEW  district:
#
# Address 2516
# Day of week 7
# Month 12
# Hour 24
# Total unique values of categorical features - 2559
#
#  Shape of district_X_features's CSR Matrix - (193281, 2559)
#
# Target shape (193281,)
#
# Features shape (193281, 2559)
#
# Stratified K folds - StratifiedKFold(n_splits=2, random_state=None, shuffle=False)
#
# TRAIN : [ 94258  94260  94262 ..., 193278 193279 193280]
# TEST : [    0     1     2 ..., 98291 98292 98293]
# Train accuracy 0 : 0.6859375
# Test accuracy 0 : 0.601866702538
#
# TRAIN : [    0     1     2 ..., 98291 98292 98293]
# TEST : [ 94258  94260  94262 ..., 193278 193279 193280]
# Train accuracy 1 : 0.681843110067
# Test accuracy 1 : 0.601603890728
# Average accuracies - Train - 0.683890305034 Test - 0.601735296633
#
# Dataframe info -
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225332 entries, 2 to 2207103
# Data columns (total 13 columns):
# address       225332 non-null object
# category      225332 non-null object
# date          225332 non-null object
# dayofweek     225332 non-null object
# descript      225332 non-null object
# incidntnum    225332 non-null int64
# location      225332 non-null object
# pddistrict    225332 non-null object
# pdid          225332 non-null int64
# resolution    225332 non-null object
# time          225332 non-null object
# x             225332 non-null float64
# y             225332 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 24.1+ MB
# None
#
# Features - Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')
#
# Unique values of features for CENTRAL district:
#
# Address 2122
# Category 39
# Day of week 7
# Descript 762
# Pd district 1
# Date 5585
# Time 1439
# X 5400
# Y 5208
# Incedent Number 188347
# Pd Id 225332
# Resolution 17
#
# Before removing null and duplicates - Rows - 225332
# Before removing null and duplicates - Columns - 5
#
# After removing null and duplicates - Rows - 213868
# After removing null and duplicates - Columns - 5
#
# Remaining features - Index(['address', 'category', 'date', 'dayofweek', 'time'], dtype='object')
#
# Preprocessed CENTRAL district Dataframe -
#
#                                         address           category  \
# 2                       0 BLOCK OF SPOFFORD LN      DRUG/NARCOTIC
# 8                    200 BLOCK OF JEFFERSON ST           TRESPASS
# 13                      1300 BLOCK OF GRANT AV       NON-CRIMINAL
# 14                       400 BLOCK OF GEARY ST            ASSAULT
# 22                       500 BLOCK OF BEACH ST            ASSAULT
# 26                2400 BLOCK OF LEAVENWORTH ST     OTHER OFFENSES
# 30                       300 BLOCK OF GEARY ST              FRAUD
# 52                     1000 BLOCK OF SUTTER ST      LARCENY/THEFT
# 53                    500 BLOCK OF COLUMBUS AV              FRAUD
# 62                        200 BLOCK OF BUSH ST      DRUG/NARCOTIC
# 69                       900 BLOCK OF GRANT AV           BURGLARY
# 71                   1000 BLOCK OF BROADWAY ST       NON-CRIMINAL
# 75                   1300 BLOCK OF COLUMBUS AV           TRESPASS
# 78        300 BLOCK OF THE EMBARCADERONORTH ST      LARCENY/THEFT
# 91                         300 BLOCK OF BAY ST            ROBBERY
# 98                      700 BLOCK OF SUTTER ST           BURGLARY
# 100                   400 BLOCK OF STOCKTON ST      LARCENY/THEFT
# 121                   500 BLOCK OF COLUMBUS AV      LARCENY/THEFT
# 134                  1400 BLOCK OF STOCKTON ST       NON-CRIMINAL
# 142                    1500 BLOCK OF POWELL ST  RECOVERED VEHICLE
# 167                      0 BLOCK OF CAMPTON PL            ASSAULT
# 187                    2900 BLOCK OF LARKIN ST       NON-CRIMINAL
# 192                   800 BLOCK OF CHESTNUT ST      LARCENY/THEFT
# 201                      200 BLOCK OF BEACH ST       NON-CRIMINAL
# 207                  600 BLOCK OF FRANCISCO ST       NON-CRIMINAL
# 213                  NORTHPOINT ST / LARKIN ST       NON-CRIMINAL
# 230                  300 BLOCK OF JEFFERSON ST            ASSAULT
# 248                       600 BLOCK OF POST ST      LARCENY/THEFT
# 253                       HYDE ST / LOMBARD ST      LARCENY/THEFT
# 254                      400 BLOCK OF BEACH ST      LARCENY/THEFT
# ...                                        ...                ...
# 2206727              NORTHPOINT ST / LARKIN ST      LARCENY/THEFT
# 2206774            1000 BLOCK OF NORTHPOINT ST      LARCENY/THEFT
# 2206783                 2200 BLOCK OF MASON ST            SUICIDE
# 2206828   300 BLOCK OF THE EMBARCADERONORTH ST       NON-CRIMINAL
# 2206836                   UNION ST / TAYLOR ST      LARCENY/THEFT
# 2206862                 700 BLOCK OF KEARNY ST      LARCENY/THEFT
# 2206867                   300 BLOCK OF POST ST      LARCENY/THEFT
# 2206875              1300 BLOCK OF COLUMBUS AV      LARCENY/THEFT
# 2206889                 LARKIN ST / PACIFIC AV            ROBBERY
# 2206926         LEIDESDORFF ST / COMMERCIAL ST        WEAPON LAWS
# 2206932                  3100 BLOCK OF POLK ST      LARCENY/THEFT
# 2206950                200 BLOCK OF SANSOME ST              FRAUD
# 2206967                    KEARNY ST / BUSH ST     OTHER OFFENSES
# 2206982                  300 BLOCK OF GRANT AV      LARCENY/THEFT
# 2206985               400 BLOCK OF STOCKTON ST           BURGLARY
# 2206988                   BATTERY ST / PINE ST            ROBBERY
# 2206992                 BROADWAY ST / DAVIS ST     OTHER OFFENSES
# 2206997                700 BLOCK OF PACIFIC AV     OTHER OFFENSES
# 2207004             900 BLOCK OF CALIFORNIA ST           BURGLARY
# 2207005                 300 BLOCK OF POWELL ST      LARCENY/THEFT
# 2207009                  400 BLOCK OF GEARY ST    STOLEN PROPERTY
# 2207015                   0 BLOCK OF KEARNY ST     OTHER OFFENSES
# 2207016                     BAY ST / KEARNY ST      LARCENY/THEFT
# 2207032                  200 BLOCK OF UNION ST     OTHER OFFENSES
# 2207045               0 BLOCK OF HIMMELMANN PL              ARSON
# 2207062                   600 BLOCK OF POST ST      LARCENY/THEFT
# 2207074                JONES ST / GREENWICH ST          VANDALISM
# 2207080  1500 BLOCK OF THE EMBARCADERONORTH ST            ASSAULT
# 2207083               400 BLOCK OF COLUMBUS AV       NON-CRIMINAL
# 2207084                 1100 BLOCK OF MASON ST       NON-CRIMINAL
#
#                             date  dayofweek   time
# 2        2017-11-06T00:00:00.000     Monday  17:06
# 8        2017-02-20T00:00:00.000     Monday  06:42
# 13       2018-03-21T00:00:00.000  Wednesday  14:45
# 14       2018-03-28T00:00:00.000  Wednesday  10:50
# 22       2010-10-16T00:00:00.000   Saturday  00:58
# 26       2015-08-20T00:00:00.000   Thursday  16:20
# 30       2013-07-29T00:00:00.000     Monday  13:00
# 52       2015-07-25T00:00:00.000   Saturday  15:45
# 53       2015-09-05T00:00:00.000   Saturday  11:30
# 62       2015-08-27T00:00:00.000   Thursday  17:44
# 69       2015-08-11T00:00:00.000    Tuesday  19:00
# 71       2013-05-26T00:00:00.000     Sunday  02:20
# 75       2015-08-04T00:00:00.000    Tuesday  14:00
# 78       2015-09-03T00:00:00.000   Thursday  21:00
# 91       2015-07-30T00:00:00.000   Thursday  12:15
# 98       2013-07-13T00:00:00.000   Saturday  02:00
# 100      2013-08-01T00:00:00.000   Thursday  11:00
# 121      2013-06-27T00:00:00.000   Thursday  15:00
# 134      2013-06-03T00:00:00.000     Monday  21:45
# 142      2015-06-09T00:00:00.000    Tuesday  00:54
# 167      2013-06-16T00:00:00.000     Sunday  01:15
# 187      2015-07-01T00:00:00.000  Wednesday  21:45
# 192      2015-07-02T00:00:00.000   Thursday  19:00
# 201      2015-06-28T00:00:00.000     Sunday  04:00
# 207      2015-06-26T00:00:00.000     Friday  04:25
# 213      2015-09-10T00:00:00.000   Thursday  19:00
# 230      2015-06-28T00:00:00.000     Sunday  01:55
# 248      2016-12-25T00:00:00.000     Sunday  09:35
# 253      2017-02-08T00:00:00.000  Wednesday  16:30
# 254      2017-03-13T00:00:00.000     Monday  20:30
# ...                          ...        ...    ...
# 2206727  2016-03-30T00:00:00.000  Wednesday  19:15
# 2206774  2016-06-16T00:00:00.000   Thursday  17:30
# 2206783  2016-02-08T00:00:00.000     Monday  09:14
# 2206828  2016-06-11T00:00:00.000   Saturday  07:44
# 2206836  2016-06-15T00:00:00.000  Wednesday  08:00
# 2206862  2016-05-08T00:00:00.000     Sunday  17:00
# 2206867  2016-05-31T00:00:00.000    Tuesday  14:46
# 2206875  2016-04-08T00:00:00.000     Friday  10:00
# 2206889  2016-06-21T00:00:00.000    Tuesday  01:30
# 2206926  2016-06-09T00:00:00.000   Thursday  09:46
# 2206932  2016-04-18T00:00:00.000     Monday  16:15
# 2206950  2016-05-17T00:00:00.000    Tuesday  20:10
# 2206967  2016-03-25T00:00:00.000     Friday  01:16
# 2206982  2016-03-04T00:00:00.000     Friday  11:37
# 2206985  2016-05-31T00:00:00.000    Tuesday  18:00
# 2206988  2016-05-26T00:00:00.000   Thursday  19:54
# 2206992  2016-03-18T00:00:00.000     Friday  11:09
# 2206997  2016-04-29T00:00:00.000     Friday  02:30
# 2207004  2016-06-06T00:00:00.000     Monday  22:00
# 2207005  2016-05-28T00:00:00.000   Saturday  21:17
# 2207009  2016-03-25T00:00:00.000     Friday  08:30
# 2207015  2016-03-18T00:00:00.000     Friday  12:30
# 2207016  2016-04-22T00:00:00.000     Friday  16:30
# 2207032  2015-08-04T00:00:00.000    Tuesday  08:00
# 2207045  2016-03-18T00:00:00.000     Friday  23:00
# 2207062  2016-05-01T00:00:00.000     Sunday  01:00
# 2207074  2016-04-07T00:00:00.000   Thursday  02:10
# 2207080  2016-03-12T00:00:00.000   Saturday  16:30
# 2207083  2016-06-07T00:00:00.000    Tuesday  15:38
# 2207084  2016-05-27T00:00:00.000     Friday  11:00
#
# [213868 rows x 5 columns]
# After adding features - Rows - 213868
# After adding features - Columns - 9
#
# New features - Index(['address', 'category', 'date', 'dayofweek', 'time', 'day', 'month',
#        'hour', 'year'],
#       dtype='object')
#
# Unique crime categories - ['DRUG/NARCOTIC' 'TRESPASS' 'NON-CRIMINAL' 'ASSAULT' 'OTHER OFFENSES'
#  'FRAUD' 'LARCENY/THEFT' 'BURGLARY' 'ROBBERY' 'RECOVERED VEHICLE'
#  'DISORDERLY CONDUCT' 'VANDALISM' 'VEHICLE THEFT' 'SUSPICIOUS OCC'
#  'MISSING PERSON' 'FORGERY/COUNTERFEITING' 'ARSON' 'WARRANTS'
#  'STOLEN PROPERTY' 'WEAPON LAWS' 'SECONDARY CODES' 'SEX OFFENSES, FORCIBLE'
#  'DRIVING UNDER THE INFLUENCE' 'GAMBLING' 'PROSTITUTION' 'EMBEZZLEMENT'
#  'RUNAWAY' 'LIQUOR LAWS' 'BRIBERY' 'KIDNAPPING' 'LOITERING' 'DRUNKENNESS'
#  'SEX OFFENSES, NON FORCIBLE' 'SUICIDE' 'EXTORTION' 'BAD CHECKS'
#  'FAMILY OFFENSES' 'TREA' 'PORNOGRAPHY/OBSCENE MAT']
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
#  district_acmdh - Index Crime - Mean - 1.1341293254664329
#
#  district_acmdh - Non Index Crime - Mean - 1.2279621085697459
#
# Index Crime Hotspots - 1095
#
# Non Index Crime Hotspots - 1374
#
# Total Index and Non Index Crime Hotspots - 1484
#
# Before considering hotspots - Rows - 213868
# Before considering hotspots - Columns - 5
#
# After considering hotspots - Rows - 209040
# After considering hotspots - Columns - 5
#
# Data shrunk from 213868  rows to 209040 rows - By ~ 99.02257467222773 % - for  CENTRAL district.
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
# Target shape (209040,)
#
# Features shape (209040, 4)
#
# Index - Non Index crime counts -
#  Index Crime (More Serious)        110830
# Non Index Crime (Less Serious)     98210
# dtype: int64
#
# Unique values of attributes for  CENTRAL  district:
#
# Address 1484
# Day of week 7
# Month 12
# Hour 24
# Total unique values of categorical features - 1527
#
#  Shape of district_X_features's CSR Matrix - (209040, 1527)
#
# Target shape (209040,)
#
# Features shape (209040, 1527)
#
# Stratified K folds - StratifiedKFold(n_splits=2, random_state=None, shuffle=False)
#
# TRAIN : [103657 103658 103659 ..., 209037 209038 209039]
# TEST : [     0      1      2 ..., 105440 105442 105445]
# Train accuracy 0 : 0.654008802143
# Test accuracy 0 : 0.587849215461
#
# TRAIN : [     0      1      2 ..., 105440 105442 105445]
# TEST : [103657 103658 103659 ..., 209037 209038 209039]
# Train accuracy 1 : 0.650411404516
# Test accuracy 1 : 0.587035973976
# Average accuracies - Train - 0.65221010333 Test - 0.587442594719
#
# Dataframe info -
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193560 entries, 28 to 2207093
# Data columns (total 13 columns):
# address       193560 non-null object
# category      193560 non-null object
# date          193560 non-null object
# dayofweek     193560 non-null object
# descript      193560 non-null object
# incidntnum    193560 non-null int64
# location      193560 non-null object
# pddistrict    193560 non-null object
# pdid          193560 non-null int64
# resolution    193560 non-null object
# time          193560 non-null object
# x             193560 non-null float64
# y             193560 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 20.7+ MB
# None
#
# Features - Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')
#
# Unique values of features for INGLESIDE district:
#
# Address 4570
# Category 39
# Day of week 7
# Descript 755
# Pd district 1
# Date 5587
# Time 1439
# X 11134
# Y 10748
# Incedent Number 152617
# Pd Id 193560
# Resolution 17
#
# Before removing null and duplicates - Rows - 193560
# Before removing null and duplicates - Columns - 5
#
# After removing null and duplicates - Rows - 177390
# After removing null and duplicates - Columns - 5
#
# Remaining features - Index(['address', 'category', 'date', 'dayofweek', 'time'], dtype='object')
#
# Preprocessed INGLESIDE district Dataframe -
#
#                               address                category  \
# 28          SANTOS ST / BROOKDALE AV          OTHER OFFENSES
# 29             300 BLOCK OF AMBER DR            NON-CRIMINAL
# 35          3300 BLOCK OF MISSION ST         SECONDARY CODES
# 40         ROUSSEAU ST / BOSWORTH ST          OTHER OFFENSES
# 68          CRESCENT AV / ANDOVER ST          OTHER OFFENSES
# 82             0 BLOCK OF ROSELLA CT                WARRANTS
# 84             ALEMANY BL / OCEAN AV           LARCENY/THEFT
# 94            ONONDAGA AV / OCEAN AV                 ASSAULT
# 104      200 BLOCK OF CRESTAVISTA DR                 SUICIDE
# 131            400 BLOCK OF PARIS ST           VEHICLE THEFT
# 174         1000 BLOCK OF BOWDOIN ST          OTHER OFFENSES
# 178          1500 BLOCK OF GENEVA AV          OTHER OFFENSES
# 181           500 BLOCK OF JUDSON AV           VEHICLE THEFT
# 182           300 BLOCK OF MOLIMO DR           LARCENY/THEFT
# 183       1400 BLOCK OF BIRCHWOOD CT            NON-CRIMINAL
# 196              0 BLOCK OF OCEAN AV                 ROBBERY
# 202          200 BLOCK OF ADDISON ST  SEX OFFENSES, FORCIBLE
# 243           100 BLOCK OF LOWELL ST           VEHICLE THEFT
# 249       600 BLOCK OF VISITACION AV           VEHICLE THEFT
# 268          500 BLOCK OF PORTOLA DR           LARCENY/THEFT
# 271            LISBON ST / BRAZIL AV               VANDALISM
# 274          100 BLOCK OF BRITTON ST         SECONDARY CODES
# 284      MOUNT VERNON AV / CAYUGA AV          OTHER OFFENSES
# 294        200 BLOCK OF BALTIMORE WY            NON-CRIMINAL
# 296        900 BLOCK OF ELLSWORTH ST                 ASSAULT
# 327           FOLSOM ST / ALEMANY BL                 ASSAULT
# 329          0 BLOCK OF CAMBRIDGE ST               VANDALISM
# 330              0 BLOCK OF OCEAN AV                WARRANTS
# 357             BOSWORTH ST / ELK ST                WARRANTS
# 368           100 BLOCK OF PUTNAM ST          SUSPICIOUS OCC
# ...                              ...                     ...
# 2206685    100 BLOCK OF ARLINGTON ST                BURGLARY
# 2206708       900 BLOCK OF GENEVA AV          OTHER OFFENSES
# 2206726       200 BLOCK OF SANTOS ST                WARRANTS
# 2206773        JARBOE AV / BRONTE ST                WARRANTS
# 2206788     500 BLOCK OF TOMPKINS AV           LARCENY/THEFT
# 2206789       200 BLOCK OF BRAZIL AV               VANDALISM
# 2206794        GENEVA AV / DELANO AV          OTHER OFFENSES
# 2206799      500 BLOCK OF VELASCO AV               VANDALISM
# 2206809       0 BLOCK OF CRESCENT AV           VEHICLE THEFT
# 2206811     5400 BLOCK OF MISSION ST          OTHER OFFENSES
# 2206817   1200 BLOCK OF SUNNYDALE AV          OTHER OFFENSES
# 2206843         0 BLOCK OF ATHENS ST         SECONDARY CODES
# 2206853       OTTAWA AV / ALEMANY BL          OTHER OFFENSES
# 2206865         0 BLOCK OF SANTOS ST          SUSPICIOUS OCC
# 2206872      GENEVA AV / SAN JOSE AV          OTHER OFFENSES
# 2206880     1400 BLOCK OF DOLORES ST            NON-CRIMINAL
# 2206906     3400 BLOCK OF MISSION ST                 ASSAULT
# 2206921        0 BLOCK OF RAYMOND AV          OTHER OFFENSES
# 2206937     3200 BLOCK OF MISSION ST          OTHER OFFENSES
# 2206941     800 BLOCK OF FOERSTER ST          OTHER OFFENSES
# 2206980           0 BLOCK OF 29TH ST             DRUNKENNESS
# 2206994            0 BLOCK OF ORA WY          OTHER OFFENSES
# 2206996     200 BLOCK OF BRADFORD ST          OTHER OFFENSES
# 2207019    VISITACION AV / SAWYER ST                 ASSAULT
# 2207023     4600 BLOCK OF MISSION ST          OTHER OFFENSES
# 2207036      200 BLOCK OF PRECITA AV                BURGLARY
# 2207043         0 BLOCK OF PERSIA AV            NON-CRIMINAL
# 2207046       BREWSTER ST / COSTA ST           LARCENY/THEFT
# 2207056    0 BLOCK OF SANTAMARINA ST               VANDALISM
# 2207093       200 BLOCK OF PUTNAM ST            NON-CRIMINAL
#
#                             date  dayofweek   time
# 28       2012-10-02T00:00:00.000    Tuesday  17:40
# 29       2013-06-05T00:00:00.000  Wednesday  14:40
# 35       2015-07-09T00:00:00.000   Thursday  18:20
# 40       2016-06-16T00:00:00.000   Thursday  17:01
# 68       2015-09-12T00:00:00.000   Saturday  16:55
# 82       2015-07-26T00:00:00.000     Sunday  12:42
# 84       2015-08-30T00:00:00.000     Sunday  19:00
# 94       2013-04-22T00:00:00.000     Monday  15:48
# 104      2013-05-22T00:00:00.000  Wednesday  05:10
# 131      2013-07-08T00:00:00.000     Monday  23:30
# 174      2013-05-08T00:00:00.000  Wednesday  08:23
# 178      2013-10-31T00:00:00.000   Thursday  00:16
# 181      2015-07-13T00:00:00.000     Monday  23:30
# 182      2015-09-12T00:00:00.000   Saturday  08:00
# 183      2015-09-02T00:00:00.000  Wednesday  19:53
# 196      2015-06-17T00:00:00.000  Wednesday  19:58
# 202      2015-08-22T00:00:00.000   Saturday  16:00
# 243      2015-09-13T00:00:00.000     Sunday  13:00
# 249      2013-06-14T00:00:00.000     Friday  20:30
# 268      2017-02-27T00:00:00.000     Monday  13:00
# 271      2012-03-01T00:00:00.000   Thursday  18:00
# 274      2013-04-26T00:00:00.000     Friday  08:42
# 284      2015-06-22T00:00:00.000     Monday  22:13
# 294      2015-07-31T00:00:00.000     Friday  09:00
# 296      2015-07-05T00:00:00.000     Sunday  23:30
# 327      2015-06-15T00:00:00.000     Monday  18:18
# 329      2015-05-18T00:00:00.000     Monday  18:45
# 330      2015-04-15T00:00:00.000  Wednesday  14:15
# 357      2015-09-06T00:00:00.000     Sunday  10:45
# 368      2015-08-12T00:00:00.000  Wednesday  05:01
# ...                          ...        ...    ...
# 2206685  2016-03-28T00:00:00.000     Monday  08:48
# 2206708  2016-05-13T00:00:00.000     Friday  23:15
# 2206726  2016-04-01T00:00:00.000     Friday  12:00
# 2206773  2016-04-15T00:00:00.000     Friday  08:43
# 2206788  2016-03-25T00:00:00.000     Friday  13:40
# 2206789  2016-03-21T00:00:00.000     Monday  22:30
# 2206794  2016-04-16T00:00:00.000   Saturday  13:40
# 2206799  2016-05-01T00:00:00.000     Sunday  21:25
# 2206809  2016-02-25T00:00:00.000   Thursday  19:30
# 2206811  2016-05-17T00:00:00.000    Tuesday  22:10
# 2206817  2016-06-16T00:00:00.000   Thursday  12:01
# 2206843  2016-03-14T00:00:00.000     Monday  16:00
# 2206853  2016-03-09T00:00:00.000  Wednesday  19:00
# 2206865  2016-06-01T00:00:00.000  Wednesday  21:15
# 2206872  2016-06-07T00:00:00.000    Tuesday  18:58
# 2206880  2016-04-05T00:00:00.000    Tuesday  11:00
# 2206906  2016-04-01T00:00:00.000     Friday  19:32
# 2206921  2016-02-24T00:00:00.000  Wednesday  23:00
# 2206937  2016-04-29T00:00:00.000     Friday  14:42
# 2206941  2016-06-18T00:00:00.000   Saturday  18:50
# 2206980  2016-06-17T00:00:00.000     Friday  09:15
# 2206994  2016-04-04T00:00:00.000     Monday  15:48
# 2206996  2016-02-26T00:00:00.000     Friday  12:00
# 2207019  2016-03-07T00:00:00.000     Monday  09:57
# 2207023  2016-04-03T00:00:00.000     Sunday  02:00
# 2207036  2016-04-22T00:00:00.000     Friday  21:45
# 2207043  2016-06-21T00:00:00.000    Tuesday  15:50
# 2207046  2016-05-20T00:00:00.000     Friday  17:00
# 2207056  2016-06-07T00:00:00.000    Tuesday  18:30
# 2207093  2016-06-02T00:00:00.000   Thursday  18:30
#
# [177390 rows x 5 columns]
# After adding features - Rows - 177390
# After adding features - Columns - 9
#
# New features - Index(['address', 'category', 'date', 'dayofweek', 'time', 'day', 'month',
#        'hour', 'year'],
#       dtype='object')
#
# Unique crime categories - ['OTHER OFFENSES' 'NON-CRIMINAL' 'SECONDARY CODES' 'WARRANTS'
#  'LARCENY/THEFT' 'ASSAULT' 'SUICIDE' 'VEHICLE THEFT' 'ROBBERY'
#  'SEX OFFENSES, FORCIBLE' 'VANDALISM' 'SUSPICIOUS OCC' 'MISSING PERSON'
#  'FORGERY/COUNTERFEITING' 'STOLEN PROPERTY' 'BURGLARY' 'TRESPASS'
#  'BAD CHECKS' 'DISORDERLY CONDUCT' 'ARSON' 'FRAUD' 'KIDNAPPING'
#  'DRUG/NARCOTIC' 'SEX OFFENSES, NON FORCIBLE' 'WEAPON LAWS' 'GAMBLING'
#  'BRIBERY' 'LOITERING' 'DRUNKENNESS' 'DRIVING UNDER THE INFLUENCE'
#  'RUNAWAY' 'PROSTITUTION' 'FAMILY OFFENSES' 'RECOVERED VEHICLE' 'EXTORTION'
#  'LIQUOR LAWS' 'EMBEZZLEMENT' 'PORNOGRAPHY/OBSCENE MAT' 'TREA']
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
#  district_acmdh - Index Crime - Mean - 1.1142919700038316
#
#  district_acmdh - Non Index Crime - Mean - 1.190950158856235
#
# Index Crime Hotspots - 1603
#
# Non Index Crime Hotspots - 2276
#
# Total Index and Non Index Crime Hotspots - 2578
#
# Before considering hotspots - Rows - 177390
# Before considering hotspots - Columns - 5
#
# After considering hotspots - Rows - 165155
# After considering hotspots - Columns - 5
#
# Data shrunk from 177390  rows to 165155 rows - By ~ 99.0689723208749 % - for  INGLESIDE district.
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
# Target shape (165155,)
#
# Features shape (165155, 4)
#
# Index - Non Index crime counts -
#  Index Crime (More Serious)        74262
# Non Index Crime (Less Serious)    90893
# dtype: int64
#
# Unique values of attributes for  INGLESIDE  district:
#
# Address 2578
# Day of week 7
# Month 12
# Hour 24
# Total unique values of categorical features - 2621
#
#  Shape of district_X_features's CSR Matrix - (165155, 2621)
#
# Target shape (165155,)
#
# Features shape (165155, 2621)
#
# Stratified K folds - StratifiedKFold(n_splits=2, random_state=None, shuffle=False)
#
# TRAIN : [ 80455  80456  80458 ..., 165152 165153 165154]
# TEST : [    0     1     2 ..., 84182 84185 84186]
# Train accuracy 0 : 0.671421824479
# Test accuracy 0 : 0.556746348906
#
# TRAIN : [    0     1     2 ..., 84182 84185 84186]
# TEST : [ 80455  80456  80458 ..., 165152 165153 165154]
# Train accuracy 1 : 0.672721548112
# Test accuracy 1 : 0.562614287271
# Average accuracies - Train - 0.672071686296 Test - 0.559680318089
#
# Dataframe info -
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 298918 entries, 1 to 2207106
# Data columns (total 13 columns):
# address       298918 non-null object
# category      298918 non-null object
# date          298918 non-null object
# dayofweek     298918 non-null object
# descript      298918 non-null object
# incidntnum    298918 non-null int64
# location      298918 non-null object
# pddistrict    298918 non-null object
# pdid          298918 non-null int64
# resolution    298918 non-null object
# time          298918 non-null object
# x             298918 non-null float64
# y             298918 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 31.9+ MB
# None
#
# Features - Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')
#
# Unique values of features for MISSION district:
#
# Address 2181
# Category 39
# Day of week 7
# Descript 811
# Pd district 1
# Date 5586
# Time 1439
# X 5929
# Y 5747
# Incedent Number 228223
# Pd Id 298918
# Resolution 17
#
# Before removing null and duplicates - Rows - 298918
# Before removing null and duplicates - Columns - 5
#
# After removing null and duplicates - Rows - 275107
# After removing null and duplicates - Columns - 5
#
# Remaining features - Index(['address', 'category', 'date', 'dayofweek', 'time'], dtype='object')
#
# Preprocessed MISSION district Dataframe -
#
#                                  address                category  \
# 1              2300 BLOCK OF MISSION ST           DRUG/NARCOTIC
# 25                 DOLORES ST / 20TH ST           LARCENY/THEFT
# 43              VALENCIA ST / DUBOCE AV                 ASSAULT
# 44                 16TH ST / MISSION ST           DRUG/NARCOTIC
# 60                2300 BLOCK OF 16TH ST            NON-CRIMINAL
# 66              900 BLOCK OF POTRERO AV          OTHER OFFENSES
# 85                  24TH ST / FOLSOM ST           DRUG/NARCOTIC
# 89       500 BLOCK OF SOUTH VAN NESS AV                 ASSAULT
# 92                  400 BLOCK OF NOE ST            NON-CRIMINAL
# 101            2600 BLOCK OF MISSION ST           LARCENY/THEFT
# 105            200 BLOCK OF FAIROAKS ST                   FRAUD
# 114            2700 BLOCK OF MISSION ST          MISSING PERSON
# 118             2200 BLOCK OF MARKET ST                 ASSAULT
# 126               3000 BLOCK OF 16TH ST                 ASSAULT
# 133              LEXINGTON ST / 18TH ST           VEHICLE THEFT
# 135            900 BLOCK OF VALENCIA ST          MISSING PERSON
# 138            500 BLOCK OF VALENCIA ST            NON-CRIMINAL
# 139                16TH ST / POTRERO AV           VEHICLE THEFT
# 140             2000 BLOCK OF MARKET ST           LARCENY/THEFT
# 143               3600 BLOCK OF 19TH ST  FORGERY/COUNTERFEITING
# 159            2600 BLOCK OF MISSION ST          OTHER OFFENSES
# 168             DORLAND ST / SANCHEZ ST                WARRANTS
# 172                 CASTRO ST / 24TH ST  SEX OFFENSES, FORCIBLE
# 189                MISSION ST / 24TH ST                 ASSAULT
# 195             600 BLOCK OF ALABAMA ST                   FRAUD
# 197                  0 BLOCK OF HOFF ST           LARCENY/THEFT
# 205               2700 BLOCK OF 16TH ST                WARRANTS
# 210                 24TH ST / CHURCH ST                   FRAUD
# 211                SANCHEZ ST / FORD ST           VEHICLE THEFT
# 217                 FOLSOM ST / 22ND ST           LARCENY/THEFT
# ...                                 ...                     ...
# 2206904       1100 BLOCK OF SHOTWELL ST                BURGLARY
# 2206911           18TH ST / SHOTWELL ST                WARRANTS
# 2206913           3100 BLOCK OF 16TH ST            NON-CRIMINAL
# 2206928           3100 BLOCK OF 16TH ST           LARCENY/THEFT
# 2206940          22ND ST / HAMPSHIRE ST                 ASSAULT
# 2206943           25TH ST / VALENCIA ST           LARCENY/THEFT
# 2206949            16TH ST / MISSION ST          SUSPICIOUS OCC
# 2206951         2000 BLOCK OF MARKET ST                 ASSAULT
# 2206954           3300 BLOCK OF 20TH ST                BURGLARY
# 2206958         800 BLOCK OF POTRERO AV                 ASSAULT
# 2206968           3900 BLOCK OF 23RD ST                BURGLARY
# 2206970           3100 BLOCK OF 23RD ST                 ASSAULT
# 2206981        1900 BLOCK OF MISSION ST          OTHER OFFENSES
# 2206987            200 BLOCK OF 14TH ST          SUSPICIOUS OCC
# 2207007            24TH ST / POTRERO AV                 ASSAULT
# 2207008           3000 BLOCK OF 19TH ST          SUSPICIOUS OCC
# 2207012        3000 BLOCK OF MISSION ST             WEAPON LAWS
# 2207017            POTRERO AV / 16TH ST                 ASSAULT
# 2207022            24TH ST / MISSION ST                 ASSAULT
# 2207031            DIVISION ST / 9TH ST           LARCENY/THEFT
# 2207047       1700 BLOCK OF HARRISON ST          SUSPICIOUS OCC
# 2207054         300 BLOCK OF ALABAMA ST           VEHICLE THEFT
# 2207059         2300 BLOCK OF MARKET ST            NON-CRIMINAL
# 2207064           14TH ST / ROSEMONT PL                WARRANTS
# 2207067          400 BLOCK OF CASTRO ST                 ROBBERY
# 2207071        1000 BLOCK OF POTRERO AV                TRESPASS
# 2207073        1000 BLOCK OF POTRERO AV            NON-CRIMINAL
# 2207078           17TH ST / GUERRERO ST               VANDALISM
# 2207096         1300 BLOCK OF NATOMA ST          SUSPICIOUS OCC
# 2207099        1300 BLOCK OF ALABAMA ST           VEHICLE THEFT
#
#                             date  dayofweek   time
# 1        2017-06-22T00:00:00.000   Thursday  16:15
# 25       2015-09-10T00:00:00.000   Thursday  21:30
# 43       2015-08-27T00:00:00.000   Thursday  16:25
# 44       2015-07-28T00:00:00.000    Tuesday  11:01
# 60       2013-03-12T00:00:00.000    Tuesday  15:00
# 66       2015-06-30T00:00:00.000    Tuesday  03:39
# 85       2015-07-11T00:00:00.000   Saturday  19:03
# 89       2015-08-08T00:00:00.000   Saturday  14:30
# 92       2015-07-19T00:00:00.000     Sunday  18:51
# 101      2015-06-06T00:00:00.000   Saturday  16:52
# 105      2013-04-22T00:00:00.000     Monday  18:00
# 114      2013-08-01T00:00:00.000   Thursday  07:00
# 118      2013-07-13T00:00:00.000   Saturday  05:25
# 126      2013-05-21T00:00:00.000    Tuesday  09:20
# 133      2013-06-13T00:00:00.000   Thursday  21:00
# 135      2013-04-30T00:00:00.000    Tuesday  17:02
# 138      2013-07-02T00:00:00.000    Tuesday  15:00
# 139      2015-06-22T00:00:00.000     Monday  22:45
# 140      2015-09-17T00:00:00.000   Thursday  08:22
# 143      2015-08-02T00:00:00.000     Sunday  12:00
# 159      2015-06-04T00:00:00.000   Thursday  01:42
# 168      2013-08-04T00:00:00.000     Sunday  10:49
# 172      2015-04-09T00:00:00.000   Thursday  11:00
# 189      2015-08-25T00:00:00.000    Tuesday  22:53
# 195      2015-08-27T00:00:00.000   Thursday  11:00
# 197      2015-08-15T00:00:00.000   Saturday  17:00
# 205      2015-08-15T00:00:00.000   Saturday  09:25
# 210      2015-09-03T00:00:00.000   Thursday  00:25
# 211      2015-07-16T00:00:00.000   Thursday  12:00
# 217      2015-08-05T00:00:00.000  Wednesday  03:10
# ...                          ...        ...    ...
# 2206904  2016-03-26T00:00:00.000   Saturday  07:00
# 2206911  2016-05-07T00:00:00.000   Saturday  12:20
# 2206913  2016-06-12T00:00:00.000     Sunday  17:30
# 2206928  2016-05-14T00:00:00.000   Saturday  15:50
# 2206940  2016-03-14T00:00:00.000     Monday  22:20
# 2206943  2016-05-06T00:00:00.000     Friday  20:45
# 2206949  2016-05-30T00:00:00.000     Monday  19:29
# 2206951  2016-05-25T00:00:00.000  Wednesday  02:15
# 2206954  2016-06-11T00:00:00.000   Saturday  23:00
# 2206958  2016-04-03T00:00:00.000     Sunday  00:01
# 2206968  2016-03-26T00:00:00.000   Saturday  18:10
# 2206970  2016-02-26T00:00:00.000     Friday  01:49
# 2206981  2016-06-07T00:00:00.000    Tuesday  17:40
# 2206987  2016-04-02T00:00:00.000   Saturday  00:15
# 2207007  2016-03-10T00:00:00.000   Thursday  07:58
# 2207008  2016-05-28T00:00:00.000   Saturday  17:12
# 2207012  2016-03-28T00:00:00.000     Monday  01:34
# 2207017  2016-03-10T00:00:00.000   Thursday  01:00
# 2207022  2016-06-13T00:00:00.000     Monday  11:40
# 2207031  2016-04-27T00:00:00.000  Wednesday  11:30
# 2207047  2016-04-16T00:00:00.000   Saturday  13:30
# 2207054  2016-04-19T00:00:00.000    Tuesday  14:00
# 2207059  2016-04-19T00:00:00.000    Tuesday  19:22
# 2207064  2016-03-04T00:00:00.000     Friday  12:30
# 2207067  2016-03-21T00:00:00.000     Monday  22:00
# 2207071  2016-06-02T00:00:00.000   Thursday  12:30
# 2207073  2016-06-17T00:00:00.000     Friday  18:53
# 2207078  2016-04-22T00:00:00.000     Friday  17:00
# 2207096  2016-04-20T00:00:00.000  Wednesday  02:01
# 2207099  2016-03-20T00:00:00.000     Sunday  23:30
#
# [275107 rows x 5 columns]
# After adding features - Rows - 275107
# After adding features - Columns - 9
#
# New features - Index(['address', 'category', 'date', 'dayofweek', 'time', 'day', 'month',
#        'hour', 'year'],
#       dtype='object')
#
# Unique crime categories - ['DRUG/NARCOTIC' 'LARCENY/THEFT' 'ASSAULT' 'NON-CRIMINAL' 'OTHER OFFENSES'
#  'FRAUD' 'MISSING PERSON' 'VEHICLE THEFT' 'FORGERY/COUNTERFEITING'
#  'WARRANTS' 'SEX OFFENSES, FORCIBLE' 'BURGLARY' 'SUSPICIOUS OCC'
#  'VANDALISM' 'DISORDERLY CONDUCT' 'WEAPON LAWS' 'TRESPASS'
#  'DRIVING UNDER THE INFLUENCE' 'ROBBERY' 'SEX OFFENSES, NON FORCIBLE'
#  'SECONDARY CODES' 'STOLEN PROPERTY' 'ARSON' 'PROSTITUTION' 'DRUNKENNESS'
#  'EMBEZZLEMENT' 'KIDNAPPING' 'SUICIDE' 'FAMILY OFFENSES' 'LIQUOR LAWS'
#  'LOITERING' 'RECOVERED VEHICLE' 'EXTORTION' 'GAMBLING' 'RUNAWAY'
#  'BAD CHECKS' 'BRIBERY' 'PORNOGRAPHY/OBSCENE MAT' 'TREA']
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
#  district_acmdh - Index Crime - Mean - 1.169122807017544
#
#  district_acmdh - Non Index Crime - Mean - 1.4402061401576884
#
# Index Crime Hotspots - 1210
#
# Non Index Crime Hotspots - 1656
#
# Total Index and Non Index Crime Hotspots - 1728
#
# Before considering hotspots - Rows - 275107
# Before considering hotspots - Columns - 5
#
# After considering hotspots - Rows - 271738
# After considering hotspots - Columns - 5
#
# Data shrunk from 275107  rows to 271738 rows - By ~ 99.01224614422752 % - for  MISSION district.
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
# Target shape (271738,)
#
# Features shape (271738, 4)
#
# Index - Non Index crime counts -
#  Index Crime (More Serious)        109413
# Non Index Crime (Less Serious)    162325
# dtype: int64
#
# Unique values of attributes for  MISSION  district:
#
# Address 1728
# Day of week 7
# Month 12
# Hour 24
# Total unique values of categorical features - 1771
#
#  Shape of district_X_features's CSR Matrix - (271738, 1771)
#
# Target shape (271738,)
#
# Features shape (271738, 1771)
#
# Stratified K folds - StratifiedKFold(n_splits=2, random_state=None, shuffle=False)
#
# TRAIN : [129875 129877 129879 ..., 271735 271736 271737]
# TEST : [     0      1      2 ..., 139354 139357 139359]
# Train accuracy 0 : 0.673565519475
# Test accuracy 0 : 0.614580113344
#
# TRAIN : [     0      1      2 ..., 139354 139357 139359]
# TEST : [129875 129877 129879 ..., 271735 271736 271737]
# Train accuracy 1 : 0.671870170015
# Test accuracy 1 : 0.617761356611
# Average accuracies - Train - 0.672717844745 Test - 0.616170734977
#
# Dataframe info -
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271737 entries, 6 to 2207109
# Data columns (total 13 columns):
# address       271737 non-null object
# category      271737 non-null object
# date          271737 non-null object
# dayofweek     271737 non-null object
# descript      271737 non-null object
# incidntnum    271737 non-null int64
# location      271737 non-null object
# pddistrict    271737 non-null object
# pdid          271737 non-null int64
# resolution    271737 non-null object
# time          271737 non-null object
# x             271737 non-null float64
# y             271737 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 29.0+ MB
# None
#
# Features - Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')
#
# Unique values of features for NORTHERN district:
#
# Address 2460
# Category 39
# Day of week 7
# Descript 786
# Pd district 1
# Date 5585
# Time 1439
# X 5969
# Y 5762
# Incedent Number 220400
# Pd Id 271737
# Resolution 17
#
# Before removing null and duplicates - Rows - 271737
# Before removing null and duplicates - Columns - 5
#
# After removing null and duplicates - Rows - 254436
# After removing null and duplicates - Columns - 5
#
# Remaining features - Index(['address', 'category', 'date', 'dayofweek', 'time'], dtype='object')
#
# Preprocessed NORTHERN district Dataframe -
#
#                               address            category  \
# 6               700 BLOCK OF 14TH ST            TRESPASS
# 9        3100 BLOCK OF DIVISADERO ST      OTHER OFFENSES
# 15         2300 BLOCK OF BUCHANAN ST      OTHER OFFENSES
# 20              600 BLOCK OF EDDY ST       DRUG/NARCOTIC
# 24             100 BLOCK OF OLIVE ST      OTHER OFFENSES
# 37           JACKSON ST / WEBSTER ST        NON-CRIMINAL
# 41            1000 BLOCK OF ELLIS ST            WARRANTS
# 46       1600 BLOCK OF WASHINGTON ST             ASSAULT
# 55           200 BLOCK OF HERMANN ST        NON-CRIMINAL
# 56            LOMBARD ST / LAGUNA ST            WARRANTS
# 63            BUCHANAN ST / UNION ST             ASSAULT
# 64           FILLMORE ST / SUTTER ST       LARCENY/THEFT
# 73              0 BLOCK OF MARINA BL        NON-CRIMINAL
# 76              0 BLOCK OF LARKIN ST             ASSAULT
# 83             1100 BLOCK OF TURK ST     SECONDARY CODES
# 103         1800 BLOCK OF PACIFIC AV      OTHER OFFENSES
# 108            FRANKLIN ST / EDDY ST      OTHER OFFENSES
# 110         1100 BLOCK OF STEINER ST             ASSAULT
# 122       LOMBARD ST / DIVISADERO ST        NON-CRIMINAL
# 123           1100 BLOCK OF GEARY BL           VANDALISM
# 124            UNION ST / OCTAVIA ST       DRUG/NARCOTIC
# 127            OFARRELL ST / POLK ST            WARRANTS
# 128        2900 BLOCK OF BROADWAY ST        NON-CRIMINAL
# ...
# 158      2013-04-28T00:00:00.000     Sunday  23:12
# 184      2015-07-16T00:00:00.000   Thursday  12:00
# 193      2015-09-12T00:00:00.000   Saturday  22:20
# 251      2013-06-09T00:00:00.000     Sunday  08:00
# 252      2016-03-29T00:00:00.000    Tuesday  13:55
# 273      2012-04-10T00:00:00.000    Tuesday  12:00
# 285      2015-07-08T00:00:00.000  Wednesday  22:00
# 287      2016-06-25T00:00:00.000   Saturday  06:30
# 337      2015-08-09T00:00:00.000     Sunday  00:01
# 345      2016-10-03T00:00:00.000     Monday  15:00
# 376      2013-01-05T00:00:00.000   Saturday  12:20
# 381      2013-01-23T00:00:00.000  Wednesday  07:40
# 395      2011-11-21T00:00:00.000     Monday  18:30
# 440      2018-04-11T00:00:00.000  Wednesday  19:00
# 445      2018-04-11T00:00:00.000  Wednesday  14:00
# 454      2018-04-11T00:00:00.000  Wednesday  07:40
# ...                          ...        ...    ...
# 2206328  2016-05-26T00:00:00.000   Thursday  15:30
# 2206338  2016-04-24T00:00:00.000     Sunday  15:00
# 2206339  2016-06-18T00:00:00.000   Saturday  08:28
# 2206352  2016-05-19T00:00:00.000   Thursday  10:01
# 2206382  2016-06-08T00:00:00.000  Wednesday  18:00
# 2206385  2016-03-15T00:00:00.000    Tuesday  14:17
# 2206398  2016-06-07T00:00:00.000    Tuesday  18:17
# 2206418  2016-06-18T00:00:00.000   Saturday  12:30
# 2206480  2016-04-29T00:00:00.000     Friday  11:24
# 2206492  2016-06-01T00:00:00.000  Wednesday  22:55
# 2206502  2016-03-27T00:00:00.000     Sunday  15:54
# 2206519  2016-04-23T00:00:00.000   Saturday  18:11
# 2206529  2016-04-04T00:00:00.000     Monday  20:58
# 2206555  2016-03-05T00:00:00.000   Saturday  01:00
# 2206569  2016-04-05T00:00:00.000    Tuesday  14:09
# 2206613  2016-05-18T00:00:00.000  Wednesday  23:37
# 2206649  2016-04-19T00:00:00.000    Tuesday  09:19
# 2206659  2016-05-10T00:00:00.000    Tuesday  02:15
# 2206741  2016-05-16T00:00:00.000     Monday  16:49
# 2206800  2016-04-20T00:00:00.000  Wednesday  01:00
# 2206826  2016-04-20T00:00:00.000  Wednesday  15:45
# 2206849  2016-04-02T00:00:00.000   Saturday  21:00
# 2206874  2016-06-09T00:00:00.000   Thursday  12:40
# 2206989  2016-05-12T00:00:00.000   Thursday  02:00
# 2206990  2016-04-06T00:00:00.000  Wednesday  07:31
# 2207011  2016-05-25T00:00:00.000  Wednesday  18:30
# 2207041  2016-04-05T00:00:00.000    Tuesday  17:22
# 2207095  2015-10-01T00:00:00.000   Thursday  10:00
# 2207101  2016-04-20T00:00:00.000  Wednesday  19:30
# 2207107  2016-06-01T00:00:00.000  Wednesday  22:55
#
# [115272 rows x 5 columns]
# After adding features - Rows - 115272
# After adding features - Columns - 9
#
# New features - Index(['address', 'category', 'date', 'dayofweek', 'time', 'day', 'month',
#        'hour', 'year'],
#       dtype='object')
#
# Unique crime categories - ['ROBBERY' 'NON-CRIMINAL' 'OTHER OFFENSES' 'LARCENY/THEFT' 'ASSAULT'
#  'MISSING PERSON' 'FORGERY/COUNTERFEITING' 'SUSPICIOUS OCC' 'VEHICLE THEFT'
#  'TRESPASS' 'VANDALISM' 'SECONDARY CODES' 'WARRANTS' 'DRUG/NARCOTIC'
#  'BURGLARY' 'FRAUD' 'FAMILY OFFENSES' 'RUNAWAY' 'SEX OFFENSES, FORCIBLE'
#  'WEAPON LAWS' 'KIDNAPPING' 'ARSON' 'DRIVING UNDER THE INFLUENCE'
#  'EMBEZZLEMENT' 'STOLEN PROPERTY' 'LIQUOR LAWS' 'DRUNKENNESS'
#  'RECOVERED VEHICLE' 'LOITERING' 'DISORDERLY CONDUCT' 'SUICIDE'
#  'BAD CHECKS' 'SEX OFFENSES, NON FORCIBLE' 'EXTORTION' 'BRIBERY'
#  'PORNOGRAPHY/OBSCENE MAT' 'PROSTITUTION' 'GAMBLING']
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
#  district_acmdh - Index Crime - Mean - 1.0816407972947428
#
#  district_acmdh - Non Index Crime - Mean - 1.2552701505757307
#
# Index Crime Hotspots - 707
#
# Non Index Crime Hotspots - 1050
#
# Total Index and Non Index Crime Hotspots - 1136
#
# Before considering hotspots - Rows - 115272
# Before considering hotspots - Columns - 5
#
# After considering hotspots - Rows - 110540
# After considering hotspots - Columns - 5
#
# Data shrunk from 115272  rows to 110540 rows - By ~ 99.04105073218128 % - for  PARK district.
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
# Target shape (110540,)
#
# Features shape (110540, 4)
#
# Index - Non Index crime counts -
#  Index Crime (More Serious)        48556
# Non Index Crime (Less Serious)    61984
# dtype: int64
#
# Unique values of attributes for  PARK  district:
#
# Address 1136
# Day of week 7
# Month 12
# Hour 24
# Total unique values of categorical features - 1179
#
#  Shape of district_X_features's CSR Matrix - (110540, 1179)
#
# Target shape (110540,)
#
# Features shape (110540, 1179)
#
# Stratified K folds - StratifiedKFold(n_splits=2, random_state=None, shuffle=False)
#
# TRAIN : [ 53054  53057  53061 ..., 110537 110538 110539]
# TEST : [    0     1     2 ..., 57049 57051 57053]
# Train accuracy 0 : 0.673493757916
# Test accuracy 0 : 0.611742355708
#
# TRAIN : [    0     1     2 ..., 57049 57051 57053]
# TEST : [ 53054  53057  53061 ..., 110537 110538 110539]
# Train accuracy 1 : 0.678071286412
# Test accuracy 1 : 0.616971232133
# Average accuracies - Train - 0.675782522164 Test - 0.614356793921
#
# Dataframe info -
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116389 entries, 0 to 2207098
# Data columns (total 13 columns):
# address       116389 non-null object
# category      116389 non-null object
# date          116389 non-null object
# dayofweek     116389 non-null object
# descript      116389 non-null object
# incidntnum    116389 non-null int64
# location      116389 non-null object
# pddistrict    116389 non-null object
# pdid          116389 non-null int64
# resolution    116389 non-null object
# time          116389 non-null object
# x             116389 non-null float64
# y             116389 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 12.4+ MB
# None
#
# Features - Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')
#
# Unique values of features for RICHMOND district:
#
# Address 2558
# Category 38
# Day of week 7
# Descript 712
# Pd district 1
# Date 5585
# Time 1439
# X 6007
# Y 5834
# Incedent Number 95200
# Pd Id 116389
# Resolution 17
#
# Before removing null and duplicates - Rows - 116389
# Before removing null and duplicates - Columns - 5
#
# After removing null and duplicates - Rows - 108491
# After removing null and duplicates - Columns - 5
#
# Remaining features - Index(['address', 'category', 'date', 'dayofweek', 'time'], dtype='object')
#
# Preprocessed RICHMOND district Dataframe -
#
#                                  address         category  \
# 0           5400 BLOCK OF CALIFORNIA ST    VEHICLE THEFT
# 12          1000 BLOCK OF POINTLOBOS AV   SUSPICIOUS OCC
# 16               3700 BLOCK OF GEARY BL     NON-CRIMINAL
# 23                 400 BLOCK OF 17TH AV   MISSING PERSON
# 38                 500 BLOCK OF 19TH AV    DRUG/NARCOTIC
# 50          3000 BLOCK OF CALIFORNIA ST        VANDALISM
# 81                2900 BLOCK OF LAKE ST   OTHER OFFENSES
# 96               400 BLOCK OF EUCLID AV     NON-CRIMINAL
# 99                   GEARY BL / 10TH AV   SUSPICIOUS OCC
# 151                800 BLOCK OF 48TH AV    LARCENY/THEFT
# 166               2300 BLOCK OF LAKE ST    LARCENY/THEFT
# 169              POST ST / BRODERICK ST        VANDALISM
# 180              0 BLOCK OF CORNWALL ST     NON-CRIMINAL
# 188         7000 BLOCK OF CALIFORNIA ST    LARCENY/THEFT
# 199            1000 BLOCK OF CLEMENT ST    LARCENY/THEFT
# 204            1800 BLOCK OF CLEMENT ST    LARCENY/THEFT
# 227      PARKPRESIDIO BL / CROSSOVER DR   OTHER OFFENSES
# 233                200 BLOCK OF 22ND AV   OTHER OFFENSES
# 241                700 BLOCK OF 33RD AV   MISSING PERSON
# 256                  GEARY BL / 11TH AV   OTHER OFFENSES
# 262        500 BLOCK OF JOHNFKENNEDY DR    LARCENY/THEFT
# 265                GEARY BL / PARKER AV   OTHER OFFENSES
# 277               0 BLOCK OF MASONIC AV    LARCENY/THEFT
# 281                  8TH AV / FULTON ST     NON-CRIMINAL
# 286         1700 BLOCK OF DIVISADERO ST        VANDALISM
# 290                 CLEMENT ST / 9TH AV     NON-CRIMINAL
# 302                600 BLOCK OF 41ST AV            FRAUD
# 321            800 BLOCK OF LA PLAYA ST         WARRANTS
# 355                  0 BLOCK OF 27TH AV     NON-CRIMINAL
# 373            3100 BLOCK OF CLEMENT ST   OTHER OFFENSES
# ...                                 ...              ...
# 2206137          6900 BLOCK OF GEARY BL    LARCENY/THEFT
# 2206209              ANZA ST / BLAKE ST        VANDALISM
# 2206210           0 BLOCK OF HEATHER AV   OTHER OFFENSES
# 2206258     1000 BLOCK OF POINTLOBOS AV    LARCENY/THEFT
# 2206265      JOHNFKENNEDY DR / GREAT HY    LARCENY/THEFT
# 2206286            500 BLOCK OF 40TH AV    LARCENY/THEFT
# 2206301             7TH AV / CLEMENT ST    VEHICLE THEFT
# 2206317          6800 BLOCK OF GEARY BL    VEHICLE THEFT
# 2206343          1000 BLOCK OF GREAT HY    LARCENY/THEFT
# 2206362         CALIFORNIA ST / 21ST AV   OTHER OFFENSES
# 2206408            300 BLOCK OF 30TH AV   OTHER OFFENSES
# 2206490               ANZA ST / WOOD ST     NON-CRIMINAL
# 2206495             400 BLOCK OF 3RD AV     NON-CRIMINAL
# 2206496            400 BLOCK OF 34TH AV   OTHER OFFENSES
# 2206516            500 BLOCK OF 45TH AV   OTHER OFFENSES
# 2206635          3400 BLOCK OF GEARY BL        VANDALISM
# 2206668          FULTON ST / STANYAN ST    LARCENY/THEFT
# 2206674    2800 BLOCK OF GOLDEN GATE AV         BURGLARY
# 2206696    500 BLOCK OF JOHNFKENNEDY DR     NON-CRIMINAL
# 2206751             300 BLOCK OF 7TH AV    VEHICLE THEFT
# 2206814            600 BLOCK OF 33RD AV     NON-CRIMINAL
# 2206835            700 BLOCK OF 11TH AV  SECONDARY CODES
# 2206846     1000 BLOCK OF POINTLOBOS AV    LARCENY/THEFT
# 2206964              0 BLOCK OF LAKE ST  SECONDARY CODES
# 2207000          ARGUELLO BL / GEARY BL     NON-CRIMINAL
# 2207030            0 BLOCK OF LUPINE AV     NON-CRIMINAL
# 2207058             300 BLOCK OF 8TH AV   OTHER OFFENSES
# 2207076            400 BLOCK OF 18TH AV    LARCENY/THEFT
# 2207094       MIDDLE DR / TRANSVERSE DR     NON-CRIMINAL
# 2207098            700 BLOCK OF 43RD AV    LARCENY/THEFT
#
#                             date  dayofweek   time
# 0        2015-08-29T00:00:00.000   Saturday  13:51
# 12       2018-03-28T00:00:00.000  Wednesday  17:46
# 16       2016-02-26T00:00:00.000     Friday  15:00
# 23       2012-08-09T00:00:00.000   Thursday  01:30
# 38       2015-06-24T00:00:00.000  Wednesday  14:00
# 50       2015-08-22T00:00:00.000   Saturday  05:26
# 81       2015-06-05T00:00:00.000     Friday  12:00
# 96       2013-05-03T00:00:00.000     Friday  07:45
# 99       2013-06-23T00:00:00.000     Sunday  07:45
# 151      2013-05-08T00:00:00.000  Wednesday  18:00
# 166      2013-05-01T00:00:00.000  Wednesday  07:30
# 169      2013-06-14T00:00:00.000     Friday  22:00
# 180      2013-09-20T00:00:00.000     Friday  19:00
# 188      2015-07-01T00:00:00.000  Wednesday  13:00
# 199      2015-07-20T00:00:00.000     Monday  20:00
# 204      2015-06-16T00:00:00.000    Tuesday  14:45
# 227      2015-06-16T00:00:00.000    Tuesday  00:50
# 233      2013-07-10T00:00:00.000  Wednesday  09:30
# 241      2015-07-11T00:00:00.000   Saturday  14:05
# 256      2013-03-17T00:00:00.000     Sunday  00:45
# 262      2013-04-24T00:00:00.000  Wednesday  14:00
# 265      2013-07-09T00:00:00.000    Tuesday  04:20
# 277      2015-09-01T00:00:00.000    Tuesday  20:55
# 281      2017-03-13T00:00:00.000     Monday  05:20
# 286      2015-07-22T00:00:00.000  Wednesday  07:20
# 290      2015-09-09T00:00:00.000  Wednesday  11:30
# 302      2015-05-29T00:00:00.000     Friday  12:00
# 321      2015-08-23T00:00:00.000     Sunday  17:50
# 355      2006-06-23T00:00:00.000     Friday  20:45
# 373      2015-06-04T00:00:00.000   Thursday  04:40
# ...                          ...        ...    ...
# 2206137  2016-05-23T00:00:00.000     Monday  19:50
# 2206209  2016-05-03T00:00:00.000    Tuesday  13:30
# 2206210  2016-01-24T00:00:00.000     Sunday  00:01
# 2206258  2016-05-05T00:00:00.000   Thursday  12:00
# 2206265  2016-05-11T00:00:00.000  Wednesday  19:05
# 2206286  2016-03-20T00:00:00.000     Sunday  11:59
# 2206301  2016-03-21T00:00:00.000     Monday  07:30
# 2206317  2016-02-26T00:00:00.000     Friday  09:30
# 2206343  2016-03-01T00:00:00.000    Tuesday  12:30
# 2206362  2016-03-15T00:00:00.000    Tuesday  21:31
# 2206408  2016-03-12T00:00:00.000   Saturday  16:43
# 2206490  2016-04-20T00:00:00.000  Wednesday  21:30
# 2206495  2016-03-17T00:00:00.000   Thursday  07:53
# 2206496  2016-05-25T00:00:00.000  Wednesday  21:00
# 2206516  2016-05-12T00:00:00.000   Thursday  00:01
# 2206635  2016-06-09T00:00:00.000   Thursday  12:00
# 2206668  2016-05-30T00:00:00.000     Monday  17:00
# 2206674  2016-04-18T00:00:00.000     Monday  00:25
# 2206696  2016-05-10T00:00:00.000    Tuesday  14:30
# 2206751  2016-03-13T00:00:00.000     Sunday  21:00
# 2206814  2016-04-27T00:00:00.000  Wednesday  22:59
# 2206835  2016-03-05T00:00:00.000   Saturday  19:00
# 2206846  2016-04-27T00:00:00.000  Wednesday  12:45
# 2206964  2016-06-08T00:00:00.000  Wednesday  13:47
# 2207000  2016-05-13T00:00:00.000     Friday  12:50
# 2207030  2016-05-23T00:00:00.000     Monday  12:00
# 2207058  2016-04-12T00:00:00.000    Tuesday  13:30
# 2207076  2016-05-14T00:00:00.000   Saturday  19:25
# 2207094  2016-04-18T00:00:00.000     Monday  12:30
# 2207098  2016-05-25T00:00:00.000  Wednesday  13:45
#
# [108491 rows x 5 columns]
# After adding features - Rows - 108491
# After adding features - Columns - 9
#
# New features - Index(['address', 'category', 'date', 'dayofweek', 'time', 'day', 'month',
#        'hour', 'year'],
#       dtype='object')
#
# Unique crime categories - ['VEHICLE THEFT' 'SUSPICIOUS OCC' 'NON-CRIMINAL' 'MISSING PERSON'
#  'DRUG/NARCOTIC' 'VANDALISM' 'OTHER OFFENSES' 'LARCENY/THEFT' 'FRAUD'
#  'WARRANTS' 'BURGLARY' 'ASSAULT' 'SECONDARY CODES' 'TRESPASS' 'ROBBERY'
#  'STOLEN PROPERTY' 'FORGERY/COUNTERFEITING' 'SEX OFFENSES, FORCIBLE'
#  'DRIVING UNDER THE INFLUENCE' 'EMBEZZLEMENT' 'RUNAWAY' 'BAD CHECKS'
#  'ARSON' 'EXTORTION' 'LIQUOR LAWS' 'RECOVERED VEHICLE' 'DRUNKENNESS'
#  'WEAPON LAWS' 'DISORDERLY CONDUCT' 'LOITERING' 'KIDNAPPING'
#  'FAMILY OFFENSES' 'BRIBERY' 'SEX OFFENSES, NON FORCIBLE' 'SUICIDE'
#  'PROSTITUTION' 'PORNOGRAPHY/OBSCENE MAT' 'GAMBLING']
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
#  district_acmdh - Index Crime - Mean - 1.1160716151001735
#
#  district_acmdh - Non Index Crime - Mean - 1.1863501227971907
#
# Index Crime Hotspots - 983
#
# Non Index Crime Hotspots - 1544
#
# Total Index and Non Index Crime Hotspots - 1674
#
# Before considering hotspots - Rows - 108491
# Before considering hotspots - Columns - 5
#
# After considering hotspots - Rows - 100950
# After considering hotspots - Columns - 5
#
# Data shrunk from 108491  rows to 100950 rows - By ~ 99.06950806979381 % - for  RICHMOND district.
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
# Target shape (100950,)
#
# Features shape (100950, 4)
#
# Index - Non Index crime counts -
#  Index Crime (More Serious)        49116
# Non Index Crime (Less Serious)    51834
# dtype: int64
#
# Unique values of attributes for  RICHMOND  district:
#
# Address 1674
# Day of week 7
# Month 12
# Hour 24
# Total unique values of categorical features - 1717
#
#  Shape of district_X_features's CSR Matrix - (100950, 1717)
#
# Target shape (100950,)
#
# Features shape (100950, 1717)
#
# Stratified K folds - StratifiedKFold(n_splits=2, random_state=None, shuffle=False)
#
# TRAIN : [ 49090  49093  49097 ..., 100947 100948 100949]
# TEST : [    0     1     2 ..., 51912 51915 51916]
# Train accuracy 0 : 0.699970282318
# Test accuracy 0 : 0.562179296682
#
# TRAIN : [    0     1     2 ..., 51912 51915 51916]
# TEST : [ 49090  49093  49097 ..., 100947 100948 100949]
# Train accuracy 1 : 0.704051510649
# Test accuracy 1 : 0.560792471521
# Average accuracies - Train - 0.702010896483 Test - 0.561485884101

# %%
process_district(city_data['City'], 'city')
# Out:
# Dataframe info -
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2207110 entries, 0 to 2207109
# Data columns (total 13 columns):
# address       object
# category      object
# date          object
# dayofweek     object
# descript      object
# incidntnum    int64
# location      object
# pddistrict    object
# pdid          int64
# resolution    object
# time          object
# x             float64
# y             float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 218.9+ MB
# None
#
# Features - Index(['address', 'category', 'date', 'dayofweek', 'descript', 'incidntnum',
#        'location', 'pddistrict', 'pdid', 'resolution', 'time', 'x', 'y'],
#       dtype='object')
#
# Unique values of features for city district:
#
# Address 25141
# Category 39
# Day of week 7
# Descript 915
# Pd district 11
# Date 5587
# Time 1439
# X 60498
# Y 58562
# Incedent Number 1740910
# Pd Id 2207110
# Resolution 17
#
# Before removing null and duplicates - Rows - 2207110
# Before removing null and duplicates - Columns - 5
#
# After removing null and duplicates - Rows - 2042021
# After removing null and duplicates - Columns - 5
#
# Remaining features - Index(['address', 'category', 'date', 'dayofweek', 'time'], dtype='object')
#
# Preprocessed city district Dataframe -
#
#                                         address           category  \
# 0                  5400 BLOCK OF CALIFORNIA ST      VEHICLE THEFT
# 1                     2300 BLOCK OF MISSION ST      DRUG/NARCOTIC
# 2                       0 BLOCK OF SPOFFORD LN      DRUG/NARCOTIC
# 3                         1000 BLOCK OF KEY AV     MISSING PERSON
# 4                      2000 BLOCK OF IRVING ST          VANDALISM
# 5                          WAWONA ST / 22ND AV       NON-CRIMINAL
# 6                         700 BLOCK OF 14TH ST           TRESPASS
# 7                   1500 BLOCK OF UNDERWOOD AV     OTHER OFFENSES
# 8                    200 BLOCK OF JEFFERSON ST           TRESPASS
# 9                  3100 BLOCK OF DIVISADERO ST     OTHER OFFENSES
# 10                      700 BLOCK OF NATOMA ST     OTHER OFFENSES
# 11                     0 BLOCK OF SOUTHPARK AV      VEHICLE THEFT
# 12                 1000 BLOCK OF POINTLOBOS AV     SUSPICIOUS OCC
# 13                      1300 BLOCK OF GRANT AV       NON-CRIMINAL
# 14                       400 BLOCK OF GEARY ST            ASSAULT
# 15                   2300 BLOCK OF BUCHANAN ST     OTHER OFFENSES
# 16                      3700 BLOCK OF GEARY BL       NON-CRIMINAL
# 17                       STANYAN ST / HAYES ST            ROBBERY
# 18                      900 BLOCK OF MARKET ST     OTHER OFFENSES
# 20                        600 BLOCK OF EDDY ST      DRUG/NARCOTIC
# 21                       2400 BLOCK OF 42ND AV            RUNAWAY
# 22                       500 BLOCK OF BEACH ST            ASSAULT
# 23                        400 BLOCK OF 17TH AV     MISSING PERSON
# 24                       100 BLOCK OF OLIVE ST     OTHER OFFENSES
# 25                        DOLORES ST / 20TH ST      LARCENY/THEFT
# 26                2400 BLOCK OF LEAVENWORTH ST     OTHER OFFENSES
# 27                      800 BLOCK OF BRYANT ST       NON-CRIMINAL
# 28                    SANTOS ST / BROOKDALE AV     OTHER OFFENSES
# 29                       300 BLOCK OF AMBER DR       NON-CRIMINAL
# 30                       300 BLOCK OF GEARY ST              FRAUD
# ...                                        ...                ...
# 2207072                 1100 BLOCK OF PALOU AV  RECOVERED VEHICLE
# 2207073               1000 BLOCK OF POTRERO AV       NON-CRIMINAL
# 2207074                JONES ST / GREENWICH ST          VANDALISM
# 2207076                   400 BLOCK OF 18TH AV      LARCENY/THEFT
# 2207078                  17TH ST / GUERRERO ST          VANDALISM
# 2207079                  500 BLOCK OF ELLIS ST       NON-CRIMINAL
# 2207080  1500 BLOCK OF THE EMBARCADERONORTH ST            ASSAULT
# 2207082                 2100 BLOCK OF PALOU AV              FRAUD
# 2207083               400 BLOCK OF COLUMBUS AV       NON-CRIMINAL
# 2207084                 1100 BLOCK OF MASON ST       NON-CRIMINAL
# 2207085                300 BLOCK OF CAPITOL AV           BURGLARY
# 2207086               0 BLOCK OF MCALLISTER ST      LARCENY/THEFT
# 2207087                     6TH ST / NATOMA ST            ASSAULT
# 2207088                 2300 BLOCK OF UNION ST      LARCENY/THEFT
# 2207089               1700 BLOCK OF LASALLE AV           WARRANTS
# 2207090                    JONES ST / ELLIS ST      LARCENY/THEFT
# 2207092                    EDDY ST / LAGUNA ST            ROBBERY
# 2207093                 200 BLOCK OF PUTNAM ST       NON-CRIMINAL
# 2207094              MIDDLE DR / TRANSVERSE DR       NON-CRIMINAL
# 2207095              600 BLOCK OF FREDERICK ST     OTHER OFFENSES
# 2207096                1300 BLOCK OF NATOMA ST     SUSPICIOUS OCC
# 2207098                   700 BLOCK OF 43RD AV      LARCENY/THEFT
# 2207099               1300 BLOCK OF ALABAMA ST      VEHICLE THEFT
# 2207100                     6TH ST / NATOMA ST     OTHER OFFENSES
# 2207101                1700 BLOCK OF HAIGHT ST            ASSAULT
# 2207102                  2200 BLOCK OF 42ND AV       NON-CRIMINAL
# 2207104               200 BLOCK OF WILLIAMS AV     OTHER OFFENSES
# 2207105                   8TH ST / HARRISON ST  RECOVERED VEHICLE
# 2207107                1700 BLOCK OF HAIGHT ST     OTHER OFFENSES
# 2207109                   300 BLOCK OF FELL ST          VANDALISM
#
#                             date  dayofweek   time
# 0        2015-08-29T00:00:00.000   Saturday  13:51
# 1        2017-06-22T00:00:00.000   Thursday  16:15
# 2        2017-11-06T00:00:00.000     Monday  17:06
# 3        2017-08-01T00:00:00.000    Tuesday  20:00
# 4        2018-03-14T00:00:00.000  Wednesday  22:30
# 5        2014-10-29T00:00:00.000  Wednesday  11:45
# 6        2015-07-09T00:00:00.000   Thursday  02:14
# 7        2015-06-21T00:00:00.000     Sunday  04:08
# 8        2017-02-20T00:00:00.000     Monday  06:42
# 9        2017-04-20T00:00:00.000   Thursday  02:00
# 10       2017-11-08T00:00:00.000  Wednesday  15:50
# 11       2018-03-23T00:00:00.000     Friday  13:15
# 12       2018-03-28T00:00:00.000  Wednesday  17:46
# 13       2018-03-21T00:00:00.000  Wednesday  14:45
# 14       2018-03-28T00:00:00.000  Wednesday  10:50
# 15       2016-03-31T00:00:00.000   Thursday  04:00
# 16       2016-02-26T00:00:00.000     Friday  15:00
# 17       2016-06-12T00:00:00.000     Sunday  17:01
# 18       2017-01-08T00:00:00.000     Sunday  19:59
# 20       2018-04-10T00:00:00.000    Tuesday  15:00
# 21       2010-12-26T00:00:00.000     Sunday  22:30
# 22       2010-10-16T00:00:00.000   Saturday  00:58
# 23       2012-08-09T00:00:00.000   Thursday  01:30
# 24       2013-05-24T00:00:00.000     Friday  17:30
# 25       2015-09-10T00:00:00.000   Thursday  21:30
# 26       2015-08-20T00:00:00.000   Thursday  16:20
# 27       2012-08-29T00:00:00.000  Wednesday  16:15
# 28       2012-10-02T00:00:00.000    Tuesday  17:40
# 29       2013-06-05T00:00:00.000  Wednesday  14:40
# 30       2013-07-29T00:00:00.000     Monday  13:00
# ...                          ...        ...    ...
# 2207072  2016-04-30T00:00:00.000   Saturday  14:07
# 2207073  2016-06-17T00:00:00.000     Friday  18:53
# 2207074  2016-04-07T00:00:00.000   Thursday  02:10
# 2207076  2016-05-14T00:00:00.000   Saturday  19:25
# 2207078  2016-04-22T00:00:00.000     Friday  17:00
# 2207079  2016-03-27T00:00:00.000     Sunday  04:00
# 2207080  2016-03-12T00:00:00.000   Saturday  16:30
# 2207082  2016-06-06T00:00:00.000     Monday  15:45
# 2207083  2016-06-07T00:00:00.000    Tuesday  15:38
# 2207084  2016-05-27T00:00:00.000     Friday  11:00
# 2207085  2016-03-23T00:00:00.000  Wednesday  07:30
# 2207086  2016-06-04T00:00:00.000   Saturday  09:00
# 2207087  2016-04-15T00:00:00.000     Friday  02:00
# 2207088  2016-03-23T00:00:00.000  Wednesday  09:42
# 2207089  2016-03-02T00:00:00.000  Wednesday  08:41
# 2207090  2016-05-06T00:00:00.000     Friday  05:45
# 2207092  2016-06-18T00:00:00.000   Saturday  18:40
# 2207093  2016-06-02T00:00:00.000   Thursday  18:30
# 2207094  2016-04-18T00:00:00.000     Monday  12:30
# 2207095  2015-10-01T00:00:00.000   Thursday  10:00
# 2207096  2016-04-20T00:00:00.000  Wednesday  02:01
# 2207098  2016-05-25T00:00:00.000  Wednesday  13:45
# 2207099  2016-03-20T00:00:00.000     Sunday  23:30
# 2207100  2016-05-18T00:00:00.000  Wednesday  07:04
# 2207101  2016-04-20T00:00:00.000  Wednesday  19:30
# 2207102  2016-05-19T00:00:00.000   Thursday  20:00
# 2207104  2016-06-19T00:00:00.000     Sunday  00:50
# 2207105  2016-03-07T00:00:00.000     Monday  00:44
# 2207107  2016-06-01T00:00:00.000  Wednesday  22:55
# 2207109  2016-04-05T00:00:00.000    Tuesday  05:01
#
# [2042021 rows x 5 columns]
# After adding features - Rows - 2042021
# After adding features - Columns - 9
#
# New features - Index(['address', 'category', 'date', 'dayofweek', 'time', 'day', 'month',
#        'hour', 'year'],
#       dtype='object')
#
# Unique crime categories - ['VEHICLE THEFT' 'DRUG/NARCOTIC' 'MISSING PERSON' 'VANDALISM'
#  'NON-CRIMINAL' 'TRESPASS' 'OTHER OFFENSES' 'SUSPICIOUS OCC' 'ASSAULT'
#  'ROBBERY' 'RUNAWAY' 'LARCENY/THEFT' 'FRAUD' 'SECONDARY CODES' 'WARRANTS'
#  'WEAPON LAWS' 'BURGLARY' 'SUICIDE' 'STOLEN PROPERTY'
#  'FORGERY/COUNTERFEITING' 'RECOVERED VEHICLE' 'SEX OFFENSES, FORCIBLE'
#  'DISORDERLY CONDUCT' 'ARSON' 'PROSTITUTION' 'DRIVING UNDER THE INFLUENCE'
#  'KIDNAPPING' 'BAD CHECKS' 'SEX OFFENSES, NON FORCIBLE' 'LIQUOR LAWS'
#  'EMBEZZLEMENT' 'DRUNKENNESS' 'LOITERING' 'FAMILY OFFENSES' 'GAMBLING'
#  'BRIBERY' 'EXTORTION' 'PORNOGRAPHY/OBSCENE MAT' 'TREA']
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
#  district_acmdh - Index Crime - Mean - 1.1878766990007261
#
#  district_acmdh - Non Index Crime - Mean - 1.365558718773493
#
# Index Crime Hotspots - 11082
#
# Non Index Crime Hotspots - 15537
#
# Total Index and Non Index Crime Hotspots - 16945
#
# Before considering hotspots - Rows - 2042021
# Before considering hotspots - Columns - 5
#
# After considering hotspots - Rows - 1981962
# After considering hotspots - Columns - 5
#
# Data shrunk from 2042021  rows to 1981962 rows - By ~ 99.02941154865694 % - for  city district.
#
# Remaining features - Index(['address', 'dayofweek', 'month', 'hour', 'Crime_Severity'], dtype='object')
#
# Target shape (1981962,)
#
# Features shape (1981962, 4)
#
# Index - Non Index crime counts -
#  Non Index Crime (Less Serious)    1083284
# Index Crime (More Serious)         898678
# dtype: int64
#
# Unique values of attributes for  city  district:
#
# Address 16945
# Day of week 7
# Month 12
# Hour 24
# Total unique values of categorical features - 16988
#
#  Shape of district_X_features's CSR Matrix - (1981962, 16988)
#
# Target shape (1981962,)
#
# Features shape (1981962, 16988)
#
# Stratified K folds - StratifiedKFold(n_splits=2, random_state=None, shuffle=False)
#
# TRAIN : [ 970188  970189  970190 ..., 1981959 1981960 1981961]
# TEST : [      0       1       2 ..., 1007170 1007173 1007174]
# Train accuracy 0 : 0.673813120534
# Test accuracy 0 : 0.603603903607
#
# TRAIN : [      0       1       2 ..., 1007170 1007173 1007174]
# TEST : [ 970188  970189  970190 ..., 1981959 1981960 1981961]
# Train accuracy 1 : 0.666366963645
# Test accuracy 1 : 0.612363910105
# Average accuracies - Train - 0.67009004209 Test - 0.607983906856

# %%
# Execute only after executing first step
# results = accuracy_dictionary.copy()
print(accuracy_dictionary.copy())
# Out:
# {'BAYVIEW': (0.68389030503357784, 0.60173529663336844), 'CENTRAL': (0.65221010332950624, 0.58744259471871407), 'INGLESIDE': (0.6720716862955296, 0.55968031808888119), 'MISSION': (0.67271784474512009, 0.61617073497723274), 'NORTHERN': (0.66482545027179984, 0.58950951163162146), 'SOUTHERN': (0.64218041225394829, 0.61065560804843155), 'TARAVAL': (0.70277570822814461, 0.57537236915939194), 'TENDERLOIN': (0.7159481587372849, 0.70077265692378576), 'PARK': (0.67578252216392265, 0.61435679392075271), 'RICHMOND': (0.70201089648340764, 0.56148588410104017), 'city': (0.6700900420896061, 0.60798390685593362)}

# %%
district_model_accuracies = accuracy_dictionary.copy()

# %%
def process_district(district, key):
    preprocessed_district = preprocess_district(district, key)
    district_X, district_y = feature_engineer_district(preprocessed_district, key)
    accuracy_dictionary[key] = train_test_district_model(district_X, district_y, key)
    return

# %% [markdown]
# # Data Preprocessing and Data Exploration

# %%
def preprocess_district(district, key):
    
    print("\nDataframe info -")
    print(district.info())
    
    print("\nFeatures -", district.columns)
    
    # Explore Unique values of features
    print("\nUnique values of features for", key,"district: \n")
    print("Address", len(district.address.unique()))
    print("Category", len(district.category.unique()))
    print("Day of week", len(district.dayofweek.unique()))
    print("Descript", len(district.descript.unique()))
    print("Pd district", len(district.pddistrict.unique()))
    print("Date",len(district.date.unique()))
    print("Time", len(district.time.unique()))
    print("X", len(district.x.unique()))
    print("Y", len(district.y.unique()))
    print("Incedent Number", len(district.incidntnum.unique()))
    print("Pd Id", len(district.pdid.unique()))
    print("Resolution", len(district.resolution.unique()))
    
    # Explore Unique discription for each crime type
#     print("Unique descriptions for each crime: \n")
#     unique_crime_types = district['category'].unique()
#     for crime in unique_crime_types:
# #         unique_crime_descriptions = district['description'].unique()
#         temp_df = district.loc[district['category'] == crime]
#         print(crime, "-", len(temp_df['descript'].unique()), "\n")
#         print(temp_df['descript'].unique(), "\n\n")

    # Drop unwanted features - 'resolution', 'pdid', 'incidntnum', 'descript', 'pddistrict', 'location', 'x', 'y'
    district = district.drop(['resolution', 'pdid', 'incidntnum', 'descript', 'pddistrict', 'location', 'x', 'y'], axis=1)
#     print(district)

    print("\nBefore removing null and duplicates - Rows -", district.shape[0])
    print("Before removing null and duplicates - Columns -", district.shape[1])
    
    # Remove Duplicate values for same incident reporting
    district = district.drop_duplicates()
    
    # Remove Null values
    district = district.dropna()
    
    print("\nAfter removing null and duplicates - Rows -", district.shape[0])
    print("After removing null and duplicates - Columns -", district.shape[1])
    
    # Capitalize Address
    district['address'] = district.address.apply(lambda x: x.upper())
    
    print("\nRemaining features -", district.columns)
    
#     print("\nPreprocessed", key,"district Dataframe -\n\n", district)
    
    # Save preprocessed district data frame
    district.to_csv('./Preprocessed_DataFrames/Preprocessed_'+key+'_dataframe.csv', index=False, header=True, columns= ['address', 'category', 'date', 'dayofweek', 'time'])
    
    return district

# %% [markdown]
# # Feature Engineering (Extraction, Transformation, Reduction)

# %%
import re
def convert_date_to_day(dt):
    result = re.findall(r'\d{4}-(\d{2})-(\d{2})T00:00:00.000',dt)
    return result[0][1]
    
def convert_date_to_month(dt):
    result = re.findall(r'\d{4}-(\d{2})-(\d{2})T00:00:00.000',dt)
    return result[0][0]

def convert_date_to_year(dt):
    result = re.findall(r'(\d{4})-(\d{2})-(\d{2})T00:00:00.000',dt)
    return result[0][0]

def convert_time_to_hour(tm):
    result = re.findall(r'(\d{2}):\d{2}',tm)
    return result[0]

# %%
from scipy.sparse import csr_matrix

def dataframetoCSRmatrix(df):
    nrows = len(df)
    nc = len(df.columns)
    idx = {}
    tid = 0
    nnz = nc * nrows
    
    cols= df.columns
    
    for col in cols:
        df[col] = df[col].apply(str)
        for name in df[col].unique():
            idx[col+name] = tid
            tid += 1
    
    ncols = len(idx)
    
    ind = np.zeros(nnz, dtype=np.int)
    val = np.zeros(nnz, dtype=np.int)
    ptr = np.zeros(nrows+1, dtype=np.int)
    
    i=0
    n=0
    
    for index,row in df.iterrows():
        for j,col in enumerate(cols):
            ind[j+n] = idx[col+row[col]]
            val[j+n] = 1
        ptr[i+1] = ptr[i] + nc
        n += nc
        i += 1
    
    mat = csr_matrix((val,ind,ptr), shape=(nrows,ncols), dtype=np.int)
#     mat.sort_indices()   
    
    return mat

# %%
from sklearn.decomposition import RandomizedPCA, TruncatedSVD
import matplotlib.pyplot as plt

def reduce_dimentions_CSR_matrix(matrix, n_components = 30, n_iter = 20):
    
    tsvd = TruncatedSVD(n_components = n_components, n_iter = n_iter, random_state=42)
    
    reduced_matrix = tsvd.fit_transform(matrix)

    print("\nShape of matrix -", matrix.shape)
    print("\nShape of reduced_matrix -", reduced_matrix.shape)

    components = tsvd.explained_variance_
    
    print("Components values -", components)
    
    # Plot component's explained variance graph to find inflection point
    plt.plot(components)
    plt.show()
    
    return reduced_matrix

# %%
def feature_engineer_district(district, key, dimentionality_reduction = False):
    
    # Extract 'day', 'month' and 'year' from 'date' feature and 'hour' from 'time' feature
    
    # Extract day
    district['day'] = district.date.apply(lambda x: convert_date_to_day(x))
    
    # Extract month
    district['month'] = district.date.apply(lambda x: convert_date_to_month(x))
    
    # Extract hour
    district['hour'] = district.time.apply(lambda x: convert_time_to_hour(x))
    
    # Extract year
    district['year'] = district.date.apply(lambda x: convert_date_to_year(x))
    
    print("\nAfter adding features - Rows -", district.shape[0])
    print("After adding features - Columns -", district.shape[1])
    
    print("\nNew features -", district.columns)
    
#     print("\nFeature Engineered", key,"district Dataframe -\n\n", district)
    
    # Removing unwanted features based on random forest's feature importance values
    district = district.drop(['date', 'time', 'year', 'day'], axis=1)
    
    # Mapping crime category to index and non-index crime based on FBI standards
    # http://gis.chicagopolice.org/clearmap_crime_sums/crime_types.html#N26
    
    print("\nUnique crime categories -", district['category'].unique())
    
#     print("\n Unique crime category incedents count -\n",pd.DataFrame({'Category_Count' : district.groupby(['category']).size()}).reset_index())
    
    # Define Index Crimes (More Serious)
    Index_crimes = ['ROBBERY', 'VEHICLE THEFT', 'BURGLARY', 'LARCENY/THEFT', 'ASSAULT', 'ARSON', 'SEX OFFENSES, FORCIBLE', 'SECONDARY CODES',  'RECOVERED VEHICLE']
#     print("\nIndex Crimes -", Index_crimes,"\nCount -",len(Index_crimes))
    
    # Define Non-Index Crimes (Less Serious)
    Non_Index_crimes = ['OTHER OFFENSES', 'NON-CRIMINAL', 'SUSPICIOUS OCC', 'FRAUD', 'FORGERY/COUNTERFEITING', 'WARRANTS', 'VANDALISM', 'MISSING PERSON', 'DISORDERLY CONDUCT', 'TRESPASS', 'WEAPON LAWS', 'DRUG/NARCOTIC', 'STOLEN PROPERTY', 'DRUNKENNESS', 'EMBEZZLEMENT', 'LOITERING', 'DRIVING UNDER THE INFLUENCE', 'PROSTITUTION', 'LIQUOR LAWS', 'EXTORTION', 'RUNAWAY', 'SUICIDE', 'BAD CHECKS', 'KIDNAPPING', 'FAMILY OFFENSES', 'BRIBERY', 'GAMBLING', 'SEX OFFENSES, NON FORCIBLE', 'PORNOGRAPHY/OBSCENE MAT', 'TREA']
#     print("\nNon Index Crimes -", Non_Index_crimes,"\nCount -",len(Non_Index_crimes))
    
    # Map category to Index crimes
    district.loc[district.category.isin(Index_crimes), 'Crime_Severity'] = "Index Crime (More Serious)"
    
    # Map category to Non Index crimes
    district.loc[district.category.isin(Non_Index_crimes), 'Crime_Severity'] = "Non Index Crime (Less Serious)"
    
    # Groupby category and examin Crime_Severity
#     district_gb = district.groupby(['category'])
#     for name, group in district_gb:
#         print("\n",name)
#         print("\n",group)

    # Removing unwanted feature category
    district = district.drop(['category'], axis=1)
        
    print("\nRemaining features -", district.columns)    
        
#     print("\nFeature Engineered", key,"district Dataframe -\n\n", district)
        
    # Identifying criteria for hotspots
    # Feature Importance - address > Crime_Severity > month > day > hour - based on random forest
    
    # Group by based on 'address', 'Crime_Severity'
    district_ac = district.groupby(['address', 'Crime_Severity']).size().reset_index(name='counts')
#     print("\n", district_ac)
    
    # Group by based on 'address', 'Crime_Severity', 'month'
    district_acm = district.groupby(['address', 'Crime_Severity', 'month']).size().reset_index(name='counts')
#     print("\n", district_acm)
    
    # Group by based on 'address', 'Crime_Severity', 'month', 'dayofweek'
    district_acmd = district.groupby(['address', 'Crime_Severity','month', 'dayofweek']).size().reset_index(name='counts')
#     print("\n", district_acmd)
    
    # Group by based on 'address', 'Crime_Severity', 'month', 'dayofweek', 'hour' 
    district_acmdh = district.groupby(['address', 'Crime_Severity', 'month', 'dayofweek', 'hour']).size().reset_index(name='counts')
#     print("\n", district_acmdh)
    
    # Identify address as hotspot if number of incidents happend at that address is above mean of incidents
    
    # Seperate Index Crime data and find hotspots for Index Crime
    mask = district_acmdh['Crime_Severity'] == 'Index Crime (More Serious)'
    district_acmdh_Index_crime = district_acmdh[mask]
    mean_Index_Crime = district_acmdh_Index_crime['counts'].mean()
    mask = district_acmdh_Index_crime['counts'] >= int(mean_Index_Crime)+1
    district_hotspot_Index_crime = district_acmdh_Index_crime[mask]
    print("\n district_acmdh - Index Crime - Mean -", mean_Index_Crime)
#     print("\n",district_hotspot_Index_crime) 
    
    # Seperate Non Index Crime data and find hotspots for Non Index Crime
    mask = district_acmdh['Crime_Severity'] == 'Non Index Crime (Less Serious)'
    district_acmdh_Non_Index_crime = district_acmdh[mask]
    mean_Non_Index_Crime = district_acmdh_Non_Index_crime['counts'].mean()
    mask = district_acmdh_Non_Index_crime['counts'] >= int(mean_Non_Index_Crime)+1
    district_hotspot_Non_Index_crime = district_acmdh_Non_Index_crime[mask]
    print("\n district_acmdh - Non Index Crime - Mean -", mean_Non_Index_Crime)
#     print("\n",district_hotspot_Non_Index_crime)
    
    # Find hotspot 'addresses' for district at hand
    hotspots = set()
    Index_hotspots = district_hotspot_Index_crime['address'].unique()
    Non_Index_hotspots = district_hotspot_Non_Index_crime['address'].unique()
    print("\nIndex Crime Hotspots -", len(Index_hotspots))
    print("\nNon Index Crime Hotspots -", len(Non_Index_hotspots))
    for ih in Index_hotspots:
        hotspots.add(ih)
    for nih in Non_Index_hotspots:
        hotspots.add(nih)
    print("\nTotal Index and Non Index Crime Hotspots -", len(hotspots))
    
    datasize_before = district.shape[0]
    print("\nBefore considering hotspots - Rows -", district.shape[0])
    print("Before considering hotspots - Columns -", district.shape[1])
    
    # Filter data based on 'address' - only consider hotspot 'address'
    mask = district['address'].isin(hotspots)
    district = district[mask]
    
    datasize_after = district.shape[0]
    print("\nAfter considering hotspots - Rows -", district.shape[0])
    print("After considering hotspots - Columns -", district.shape[1])
    
    print("\nData shrunk from", datasize_before," rows to", datasize_after, "rows - By ~", 100 - (datasize_after/datasize_before), "% - for ", key,"district.")
    
    print("\nRemaining features -", district.columns)    
        
#     print("\nFeature Engineered", key,"district Dataframe -\n\n", district)
    
    # Save feature engineered district data frame
    district.to_csv('./Feature_Engineered_DataFrames/Feature_Engineered_'+key+'_dataframe.csv', index=False, header=True, columns= ['address', 'category', 'dayofweek', 'month', 'hour'])
    
    # Read feature engineered district data frame
    # district = pd.read_csv('/Feature_Engineered_DataFrames/Feature_Engineered_'+key+'_dataframe.csv',encoding = "ISO-8859-1")
    
    # Target
    district_y_crime_severity = district['Crime_Severity']
    print("\nTarget shape", district_y_crime_severity.shape)
#     print("\nTarget -\n", district_y_crime_severity)
    
    # Features
    district_X_features = district.drop(['Crime_Severity'],axis=1)
    print("\nFeatures shape", district_X_features.shape)
#     print("\nFeatures -\n", district_X_features)
    
    district_y_crime_severity_count = pd.value_counts(district_y_crime_severity.values, sort=False)
    print("\nIndex - Non Index crime counts -\n",district_y_crime_severity_count)
    
    print("\nUnique values of attributes for ", key," district: \n")
    print("Address", len(district_X_features.address.unique()))
    print("Day of week", len(district_X_features.dayofweek.unique()))
    print("Month", len(district_X_features.month.unique()))
    print("Hour", len(district_X_features.hour.unique()))
    print("Total unique values of categorical features -", len(district_X_features.hour.unique()) + len(district_X_features.month.unique()) + len(district_X_features.dayofweek.unique()) + len(district_X_features.address.unique()))
    
    # Convert categorical data to one-hot encoded data frame and convert that sparse data frame to CSR Matrix
    matrix = dataframetoCSRmatrix(district_X_features)

    print("\n Shape of district_X_features's CSR Matrix -", matrix.shape)
    
    if dimentionality_reduction:
        matrix = reduce_dimentions_CSR_matrix(matrix)
    
    # Target
    print("\nTarget shape", district_y_crime_severity.shape)
#     print("\nTarget -\n", district_y_crime_severity)
    
    # Features
    print("\nFeatures shape", matrix.shape)
#     print("\nFeatures -\n", matrix)
    
    return matrix, district_y_crime_severity.values

# %% [markdown]
# # Model Training, Testing and Evaluation

# %%
# Report best candidate function with optimal parameters for RandomizedSerach
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score

def train_test_district_model(district_X, district_y, key):
    
    n_splits = 2
    skf = StratifiedKFold(n_splits = n_splits)
    skf.get_n_splits(district_X, district_y)
    
    print("\nStratified K folds -",skf)
    
    count = 0
    
    train_accuracy = []
    test_accuracy = []
    
    for train, test in skf.split(district_X, district_y):
        
        print("\nTRAIN :", train, "\nTEST :", test)
        
        X_train, X_test = district_X[train], district_X[test]
        y_train, y_test = district_y[train], district_y[test]
        
        # Tried randomized search but it's talking too long even on AWS EC2 instance
        
#         param_dist = {
#             "solver": ['sgd', 'adam', 'lbfgs'],
#             "alpha": [0.01,0.001,1e-4,1e-5],
#             "hidden_layer_sizes": [(5, 5), (10, 5), (5, 7, 10), (10, 7, 5)],
#             "max_iter": [50, 100, 150, 200],
#             "learning_rate_init": [0.01,0.001,1e-4,1e-5]
#         }
#         n_iter_search = 20
#         random_search = RandomizedSearchCV(mlclf, param_distributions=param_dist, n_iter=n_iter_search)
#         start = time()
#         random_search.fit(X, y)
#         print("RandomizedSearchCV took %.2f seconds for %d candidates parameter settings." % ((time() - start), n_iter_search))
#         report(random_search.cv_results_)

#         mlpclf = MLPClassifier(solver='sgd', alpha=1e-5,hidden_layer_sizes=(5, 5), random_state=1)
#         mlpclf = MLPClassifier(solver='sgd', alpha=1e-5,hidden_layer_sizes=(10, 5), random_state=1)
#         mlpclf = MLPClassifier(solver='sgd', alpha=1e-5,hidden_layer_sizes=(5, 7, 10), random_state=1)
#         mlpclf = MLPClassifier(solver='sgd', alpha=1e-5,hidden_layer_sizes=(10, 7, 5), random_state=1)
        
        mlpclf = MLPClassifier(solver='adam', alpha=0.001,hidden_layer_sizes=(5, 5), random_state=1, max_iter=200)
#         mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(10, 5), random_state=1)
#         mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(5, 7, 10), random_state=1)
#         mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(10, 7, 5), random_state=1)
        
#         mlpclf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 5), random_state=1)
#         mlpclf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(10, 5), random_state=1)
#         mlpclf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 7, 10), random_state=1)
#         mlpclf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(10, 7, 5), random_state=1)
        
        mlpclf.fit(X_train, y_train)

        predicted_y_train = mlpclf.predict(X_train)
        
        train_f1_score = f1_score(y_train, predicted_y_train, average='micro')
        train_accuracy.append(train_f1_score)
        print("Train accuracy", count,":",train_f1_score)
        
        predicted_y_test = mlpclf.predict(X_test)
        
        test_f1_score = f1_score(y_test, predicted_y_test, average='micro')
        test_accuracy.append(test_f1_score)
        print("Test accuracy", count,":",test_f1_score)
        
#         print("Classification report -", classification_report(y_test,predictions))

        # Store predictions to a file
#         with open('predictions_Crime_Type_',key,'.dat','a') as file:
#             for p in predicted_y_train:
#                 file.write(str(p)+"\n")
#             for p in predicted_y_test:
#                 file.write(str(p)+"\n")
                
        count += 1
    
    total_tain_acccuracy = 0
    for ta in train_accuracy:
        total_tain_acccuracy += ta
        
    total_test_acccuracy = 0
    for ta in test_accuracy:
        total_test_acccuracy += ta
    
    avg_train_accuracy = total_tain_acccuracy/n_splits
    avg_test_accuracy = total_test_acccuracy/n_splits
    
    print("Average accuracies - Train -", avg_train_accuracy, "Test -", avg_test_accuracy)
    
    return avg_train_accuracy, avg_test_accuracy

# %% [markdown]
# # Knowledge Mining and Visualizations

# %%
# Tried parameter tuning with random different values of solver function, hidden layers & nodes, alpha, max_iter for BAYVIEW district

# %%
# MLP

# Solver selection

# 1.
# mlpclf = MLPClassifier(solver='sgd', alpha=1e-5,hidden_layer_sizes=(5, 5), random_state=1) - 
# Average accuracies - Train - 0.579875931922 Test - 0.579875931922

# 2.
# mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(5, 5), random_state=1)
# Average accuracies - Train - 0.690259253642 Test - 0.600436676233

# 3.
# mlpclf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 5), random_state=1)
# Average accuracies - Train - 0.671918101601 Test - 0.607617946048

# %%
# Hidden Layers selection

# 1.
# mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(5, 5), random_state=1)
# Average accuracies - Train - 0.690259253642 Test - 0.600436676233

# 2.
# mlpclf = MLPClassifier(solver='adam', alpha=0.001,hidden_layer_sizes=(10, 5), random_state=1)
# Average accuracies - Train - 0.742054304791 Test - 0.588138538267

# 3.
# mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(5, 7, 10), random_state=1)
# Average accuracies - Train - 0.7099973349 Test - 0.594414365124

# 4.
# mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(10, 7, 5), random_state=1)
# Average accuracies - Train - 0.739989942155 Test - 0.588154043622

# %%
# Alpha (regularization parameter selection - prevents overfitting)

# 1.
# mlpclf = MLPClassifier(solver='adam', alpha=0.01,hidden_layer_sizes=(5, 5), random_state=1)
# Average accuracies - Train - 0.66968292426 Test - 0.608502621902

# 2.
# mlpclf = MLPClassifier(solver='adam', alpha=0.001,hidden_layer_sizes=(5, 5), random_state=1)
# Average accuracies - Train - 0.683890305034 Test - 0.601735296633

# 3.
# mlpclf = MLPClassifier(solver='adam', alpha=1e-4,hidden_layer_sizes=(5, 5), random_state=1)
# Average accuracies - Train - 0.686694491125 Test - 0.598744851996

# 4.
# mlpclf = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(5, 5), random_state=1)
# Average accuracies - Train - 0.690259253642 Test - 0.600436676233

# %%
# max_iter (epochs)

# 1.
# mlpclf = MLPClassifier(solver='adam', alpha=0.001,hidden_layer_sizes=(5, 5), random_state=1, max_iter= 200)
# Average accuracies - Train - 0.690259253642 Test - 0.600436676233

# 2.
# mlpclf = MLPClassifier(solver='adam', alpha=0.001,hidden_layer_sizes=(5, 5), random_state=1, max_iter=50)
# Average accuracies - Train - 0.66968292426 Test - 0.608502621902

# 3. 
# mlpclf = MLPClassifier(solver='adam', alpha=0.001,hidden_layer_sizes=(5, 5), random_state=1, max_iter=100)
# Average accuracies - Train - 0.681386165907 Test - 0.605258671259

# 4.
# mlpclf = MLPClassifier(solver='adam', alpha=0.001,hidden_layer_sizes=(5, 5), random_state=1, max_iter=150)
# Average accuracies - Train - 0.683890305034 Test - 0.601735296633

# %%
# district wise model's accuracies
district_model_accuracies = accuracy_dictionary.copy()
results = accuracy_dictionary.copy()
district_model_accuracies
# Out:
# {'BAYVIEW': (0.68389030503357784, 0.60173529663336844),
#  'CENTRAL': (0.65221010332950624, 0.58744259471871407),
#  'INGLESIDE': (0.6720716862955296, 0.55968031808888119),
#  'MISSION': (0.67271784474512009, 0.61617073497723274),
#  'NORTHERN': (0.66482545027179984, 0.58950951163162146),
#  'PARK': (0.67578252216392265, 0.61435679392075271),
#  'RICHMOND': (0.70201089648340764, 0.56148588410104017),
#  'SOUTHERN': (0.64218041225394829, 0.61065560804843155),
#  'TARAVAL': (0.70277570822814461, 0.57537236915939194),
#  'TENDERLOIN': (0.7159481587372849, 0.70077265692378576),
#  'city': (0.6700900420896061, 0.60798390685593362)}

# %%
# 1) Simple MLP
# 2) MLP with K-fold
# 3) MLP with K-fold and TruncatedSVD
